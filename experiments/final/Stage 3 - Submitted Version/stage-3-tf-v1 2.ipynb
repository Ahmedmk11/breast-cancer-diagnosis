# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, losses
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import TensorBoard

import datetime
import os
import time
import matplotlib.pyplot as plt
import numpy as np
import shutil
import tempfile

# %%
dataset_path = '/kaggle/input/final-stage-3-v3/Stage 3 V3'

# %%
def resize_with_padding(img):
    w, h = img.shape[1], img.shape[0]
    if h > w:
        new_h = 299
        new_w = int(w * (299 / h))
    else:
        new_w = 299
        new_h = int(h * (299 / w))
    
    img = tf.image.resize(img, [new_h, new_w])
    img = tf.image.resize_with_pad(img, 299, 299)
    
    return img

# %%
temp_dir = tempfile.mkdtemp()

class_names = os.listdir(dataset_path)

os.makedirs(temp_dir + '/train')
os.makedirs(temp_dir + '/val')
os.makedirs(temp_dir + '/test')

for class_name in class_names:
    os.makedirs(temp_dir + '/train/' + class_name)
    os.makedirs(temp_dir + '/val/' + class_name)
    os.makedirs(temp_dir + '/test/' + class_name)
    
    image_names = os.listdir(dataset_path + '/' + class_name)
    np.random.shuffle(image_names)
    
    train_names = image_names[:int(len(image_names)*0.8)]
    val_names = image_names[int(len(image_names)*0.8):int(len(image_names)*0.9)]
    test_names = image_names[int(len(image_names)*0.9):]

    for name in train_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/train/' + class_name + '/' + name)
    for name in val_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/val/' + class_name + '/' + name)
    for name in test_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/test/' + class_name + '/' + name)

datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    preprocessing_function=resize_with_padding
)

train_generator = datagen.flow_from_directory(
    temp_dir + '/train',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary'
)

validation_generator = datagen.flow_from_directory(
    temp_dir + '/val',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary'
)

test_generator = datagen.flow_from_directory(
    temp_dir + '/test',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary'
)
# Out:
# Found 1292 images belonging to 2 classes.
# Found 162 images belonging to 2 classes.
# Found 163 images belonging to 2 classes.

# %%
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))  # InceptionV3 expects input size of (299, 299)

model = models.Sequential()
model.add(base_model)
model.add(layers.Flatten())

model.add(layers.Dense(512))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.5))

model.add(layers.Dense(256))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.5))

model.add(layers.Dense(1, activation='sigmoid'))

model.compile(loss=losses.BinaryCrossentropy(),
              optimizer=optimizers.Adam(learning_rate=0.00001),
              metrics=['accuracy'])

model.build(input_shape=(None, 299, 299, 3))

log_dir = "/kaggle/working/logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=True)

# %%
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', mode='min', save_best_only=True, verbose=1)
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20, verbose=1, restore_best_weights=True)

history = model.fit(
    train_generator,
    epochs=150,
    validation_data=validation_generator,
    callbacks=[checkpoint, earlystop, tensorboard_callback])
# Out:
# Epoch 1/150
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1715845296.693686     268 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1715845296.801452     268 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 966ms/step - accuracy: 0.6196 - loss: 0.6788
# W0000 00:00:1715845381.757969     266 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_loss improved from inf to 0.44388, saving model to best_model.keras
# W0000 00:00:1715845390.864822     266 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 221s 2s/step - accuracy: 0.6203 - loss: 0.6779 - val_accuracy: 0.7963 - val_loss: 0.4439
# Epoch 2/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.8066 - loss: 0.4340
# Epoch 2: val_loss improved from 0.44388 to 0.29996, saving model to best_model.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 62s 749ms/step - accuracy: 0.8066 - loss: 0.4340 - val_accuracy: 0.9012 - val_loss: 0.3000
# Epoch 3/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.8673 - loss: 0.3207
# Epoch 3: val_loss improved from 0.29996 to 0.26070, saving model to best_model.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 59s 718ms/step - accuracy: 0.8673 - loss: 0.3207 - val_accuracy: 0.9198 - val_loss: 0.2607
# Epoch 4/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.8745 - loss: 0.3043
# Epoch 4: val_loss improved from 0.26070 to 0.25609, saving model to best_model.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 59s 721ms/step - accuracy: 0.8745 - loss: 0.3042 - val_accuracy: 0.8827 - val_loss: 0.2561
# Epoch 5/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.8932 - loss: 0.2725
# Epoch 5: val_loss did not improve from 0.25609
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 652ms/step - accuracy: 0.8933 - loss: 0.2722 - val_accuracy: 0.8889 - val_loss: 0.2580
# Epoch 6/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9251 - loss: 0.1907
# Epoch 6: val_loss improved from 0.25609 to 0.23355, saving model to best_model.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 60s 724ms/step - accuracy: 0.9252 - loss: 0.1906 - val_accuracy: 0.9136 - val_loss: 0.2336
# Epoch 7/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.9280 - loss: 0.1925
# Epoch 7: val_loss improved from 0.23355 to 0.21796, saving model to best_model.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 60s 724ms/step - accuracy: 0.9280 - loss: 0.1924 - val_accuracy: 0.9321 - val_loss: 0.2180
# Epoch 8/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.9577 - loss: 0.1272
# Epoch 8: val_loss improved from 0.21796 to 0.21089, saving model to best_model.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 59s 719ms/step - accuracy: 0.9576 - loss: 0.1273 - val_accuracy: 0.9321 - val_loss: 0.2109
# Epoch 9/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.9560 - loss: 0.1335
# Epoch 9: val_loss did not improve from 0.21089
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 650ms/step - accuracy: 0.9560 - loss: 0.1335 - val_accuracy: 0.9259 - val_loss: 0.2169
# Epoch 10/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.9700 - loss: 0.1038
# Epoch 10: val_loss improved from 0.21089 to 0.19679, saving model to best_model.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 59s 719ms/step - accuracy: 0.9700 - loss: 0.1036 - val_accuracy: 0.9383 - val_loss: 0.1968
# Epoch 11/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.9613 - loss: 0.1242
# Epoch 11: val_loss did not improve from 0.19679
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 659ms/step - accuracy: 0.9613 - loss: 0.1241 - val_accuracy: 0.9198 - val_loss: 0.2022
# Epoch 12/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.9758 - loss: 0.0874
# Epoch 12: val_loss did not improve from 0.19679
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 656ms/step - accuracy: 0.9758 - loss: 0.0875 - val_accuracy: 0.9136 - val_loss: 0.2139
# Epoch 13/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9712 - loss: 0.0925
# Epoch 13: val_loss did not improve from 0.19679
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 650ms/step - accuracy: 0.9712 - loss: 0.0924 - val_accuracy: 0.9383 - val_loss: 0.2060
# Epoch 14/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9783 - loss: 0.0735
# Epoch 14: val_loss improved from 0.19679 to 0.19588, saving model to best_model.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 88s 719ms/step - accuracy: 0.9783 - loss: 0.0736 - val_accuracy: 0.9136 - val_loss: 0.1959
# Epoch 15/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.9887 - loss: 0.0639
# Epoch 15: val_loss improved from 0.19588 to 0.19165, saving model to best_model.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 59s 718ms/step - accuracy: 0.9887 - loss: 0.0640 - val_accuracy: 0.9259 - val_loss: 0.1916
# Epoch 16/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.9715 - loss: 0.0837
# Epoch 16: val_loss did not improve from 0.19165
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 656ms/step - accuracy: 0.9716 - loss: 0.0836 - val_accuracy: 0.9383 - val_loss: 0.1938
# Epoch 17/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9874 - loss: 0.0524
# Epoch 17: val_loss improved from 0.19165 to 0.17407, saving model to best_model.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 59s 717ms/step - accuracy: 0.9874 - loss: 0.0525 - val_accuracy: 0.9444 - val_loss: 0.1741
# Epoch 18/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9853 - loss: 0.0511
# Epoch 18: val_loss did not improve from 0.17407
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 651ms/step - accuracy: 0.9854 - loss: 0.0510 - val_accuracy: 0.9321 - val_loss: 0.1900
# Epoch 19/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9858 - loss: 0.0515
# Epoch 19: val_loss did not improve from 0.17407
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 651ms/step - accuracy: 0.9858 - loss: 0.0515 - val_accuracy: 0.9383 - val_loss: 0.1922
# Epoch 20/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.9795 - loss: 0.0761
# Epoch 20: val_loss did not improve from 0.17407
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 656ms/step - accuracy: 0.9796 - loss: 0.0759 - val_accuracy: 0.9383 - val_loss: 0.2047
# Epoch 21/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9902 - loss: 0.0500
# Epoch 21: val_loss did not improve from 0.17407
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 653ms/step - accuracy: 0.9901 - loss: 0.0501 - val_accuracy: 0.9383 - val_loss: 0.2256
# Epoch 22/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9776 - loss: 0.0711
# Epoch 22: val_loss did not improve from 0.17407
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 656ms/step - accuracy: 0.9778 - loss: 0.0708 - val_accuracy: 0.9321 - val_loss: 0.2230
# Epoch 23/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9929 - loss: 0.0368
# Epoch 23: val_loss did not improve from 0.17407
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 660ms/step - accuracy: 0.9929 - loss: 0.0369 - val_accuracy: 0.9321 - val_loss: 0.2005
# Epoch 24/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.9935 - loss: 0.0393
# Epoch 24: val_loss did not improve from 0.17407
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 653ms/step - accuracy: 0.9935 - loss: 0.0392 - val_accuracy: 0.9444 - val_loss: 0.1988
# Epoch 25/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9927 - loss: 0.0348
# Epoch 25: val_loss did not improve from 0.17407
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 656ms/step - accuracy: 0.9927 - loss: 0.0348 - val_accuracy: 0.9444 - val_loss: 0.2094
# Epoch 26/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9828 - loss: 0.0673
# Epoch 26: val_loss did not improve from 0.17407
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 655ms/step - accuracy: 0.9828 - loss: 0.0670 - val_accuracy: 0.9259 - val_loss: 0.2129
# Epoch 27/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9962 - loss: 0.0251
# Epoch 27: val_loss did not improve from 0.17407
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 657ms/step - accuracy: 0.9962 - loss: 0.0252 - val_accuracy: 0.9444 - val_loss: 0.2180
# Epoch 28/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.9997 - loss: 0.0228
# Epoch 28: val_loss did not improve from 0.17407
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 659ms/step - accuracy: 0.9997 - loss: 0.0229 - val_accuracy: 0.9198 - val_loss: 0.2370
# Epoch 29/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9890 - loss: 0.0417
# Epoch 29: val_loss did not improve from 0.17407
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 653ms/step - accuracy: 0.9890 - loss: 0.0417 - val_accuracy: 0.9198 - val_loss: 0.2312
# Epoch 30/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9977 - loss: 0.0250
# Epoch 30: val_loss did not improve from 0.17407
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 657ms/step - accuracy: 0.9976 - loss: 0.0251 - val_accuracy: 0.9444 - val_loss: 0.2111
# Epoch 31/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9902 - loss: 0.0392
# Epoch 31: val_loss did not improve from 0.17407
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 657ms/step - accuracy: 0.9902 - loss: 0.0391 - val_accuracy: 0.9506 - val_loss: 0.1997
# Epoch 32/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9908 - loss: 0.0355
# Epoch 32: val_loss did not improve from 0.17407
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 655ms/step - accuracy: 0.9908 - loss: 0.0355 - val_accuracy: 0.9444 - val_loss: 0.2479
# Epoch 33/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9913 - loss: 0.0297
# Epoch 33: val_loss did not improve from 0.17407
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 655ms/step - accuracy: 0.9913 - loss: 0.0297 - val_accuracy: 0.9568 - val_loss: 0.1933
# Epoch 34/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9983 - loss: 0.0219
# Epoch 34: val_loss did not improve from 0.17407
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 655ms/step - accuracy: 0.9983 - loss: 0.0219 - val_accuracy: 0.9444 - val_loss: 0.1850
# Epoch 35/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9998 - loss: 0.0210
# Epoch 35: val_loss did not improve from 0.17407
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 657ms/step - accuracy: 0.9998 - loss: 0.0209 - val_accuracy: 0.9568 - val_loss: 0.2000
# Epoch 36/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9956 - loss: 0.0265
# Epoch 36: val_loss did not improve from 0.17407
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 656ms/step - accuracy: 0.9956 - loss: 0.0265 - val_accuracy: 0.9383 - val_loss: 0.2250
# Epoch 37/150
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9997 - loss: 0.0163
# Epoch 37: val_loss did not improve from 0.17407
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 54s 658ms/step - accuracy: 0.9997 - loss: 0.0164 - val_accuracy: 0.9383 - val_loss: 0.1985
# Epoch 37: early stopping
# Restoring model weights from the end of the best epoch: 17.

# %%
max_loss_threshold = 2.0
min_accuracy_threshold = 0.8

filtered_train_loss = [v for v in history.history['loss'] if v <= max_loss_threshold]
filtered_val_loss = [v for v in history.history['val_loss'] if v <= max_loss_threshold]

filtered_train_accuracy = [v for v in history.history['accuracy'] if v >= min_accuracy_threshold]
filtered_val_accuracy = [v for v in history.history['val_accuracy'] if v >= min_accuracy_threshold]

min_len = min(len(filtered_train_loss), len(filtered_val_loss), len(filtered_train_accuracy), len(filtered_val_accuracy))
filtered_train_loss = filtered_train_loss[:min_len]
filtered_val_loss = filtered_val_loss[:min_len]
filtered_train_accuracy = filtered_train_accuracy[:min_len]
filtered_val_accuracy = filtered_val_accuracy[:min_len]

plt.figure(figsize=(10, 5))
plt.plot(filtered_train_loss, label='Training Loss')
plt.plot(filtered_val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(filtered_train_accuracy, label='Training Accuracy')
plt.plot(filtered_val_accuracy, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %%
model.load_weights('best_model.keras')

test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%')
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 957ms/step - accuracy: 0.9081 - loss: 0.1685
# W0000 00:00:1715847908.712047     266 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Test Loss: 0.1738, Test Accuracy: 0.92%
