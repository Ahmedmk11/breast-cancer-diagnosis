# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, losses
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet101, ResNet50, ResNet152, InceptionV3, InceptionResNetV2
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard, ReduceLROnPlateau

import os
import time
import matplotlib.pyplot as plt
import numpy as np
import shutil
import tempfile
# Out:
# 2024-05-18 03:59:54.552668: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-18 03:59:54.552729: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-18 03:59:54.554263: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
dataset_path = '/kaggle/input/stage-2-classification/Stage 2 Classification'

# %%
temp_dir = tempfile.mkdtemp()

class_names = os.listdir(dataset_path)

os.makedirs(temp_dir + '/train')
os.makedirs(temp_dir + '/val')
os.makedirs(temp_dir + '/test')

for class_name in class_names:
    os.makedirs(temp_dir + '/train/' + class_name)
    os.makedirs(temp_dir + '/val/' + class_name)
    os.makedirs(temp_dir + '/test/' + class_name)
    
    image_names = os.listdir(dataset_path + '/' + class_name)
    np.random.shuffle(image_names)
    
    train_names = image_names[:int(len(image_names)*0.8)]
    val_names = image_names[int(len(image_names)*0.8):int(len(image_names)*0.9)]
    test_names = image_names[int(len(image_names)*0.9):]

    for name in train_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/train/' + class_name + '/' + name)
    for name in val_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/val/' + class_name + '/' + name)
    for name in test_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/test/' + class_name + '/' + name)

datagen = ImageDataGenerator(rescale=1./255)

train_generator = datagen.flow_from_directory(
    temp_dir + '/train',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')

validation_generator = datagen.flow_from_directory(
    temp_dir + '/val',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')

test_generator = datagen.flow_from_directory(
    temp_dir + '/test',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')
# Out:
# Found 2119 images belonging to 2 classes.
# Found 265 images belonging to 2 classes.
# Found 265 images belonging to 2 classes.

# %%
base_model = InceptionResNetV2(weights='imagenet', include_top=False, input_shape=(299, 299, 3))

model = models.Sequential()
model.add(base_model)
model.add(layers.Flatten())

model.add(layers.Dense(512))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.6))

model.add(layers.Dense(256))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.6))

model.add(layers.Dense(1, activation='sigmoid'))

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6, verbose=1)
model.compile(loss=losses.BinaryCrossentropy(),
              optimizer=optimizers.AdamW(0.00001, weight_decay=0.00001),
              metrics=['accuracy'])

model.build(input_shape=(None, 299, 299, 3))

# %%
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', mode='min', save_best_only=True, verbose=1)
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, restore_best_weights=True)

log_dir = "/kaggle/working/logs/fit"
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=True)

# %%
history = model.fit(
    train_generator,
    epochs=15,
    validation_data=validation_generator,
    callbacks=[checkpoint, earlystop, tensorboard_callback, reduce_lr]
)
# Out:
# Epoch 1/15
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1716005025.624391    1512 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1716005025.906514    1512 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 125/133 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.5049 - loss: 0.9259
# W0000 00:00:1716005163.418787    1512 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5054 - loss: 0.9252
# W0000 00:00:1716005178.896175    1511 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_loss improved from inf to 0.64981, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 427s 2s/step - accuracy: 0.5055 - loss: 0.9251 - val_accuracy: 0.6151 - val_loss: 0.6498 - learning_rate: 1.0000e-05
# Epoch 2/15
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.5961 - loss: 0.7911
# Epoch 2: val_loss improved from 0.64981 to 0.60106, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 89s 664ms/step - accuracy: 0.5962 - loss: 0.7909 - val_accuracy: 0.6453 - val_loss: 0.6011 - learning_rate: 1.0000e-05
# Epoch 3/15
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.6437 - loss: 0.7261
# Epoch 3: val_loss improved from 0.60106 to 0.58968, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 90s 671ms/step - accuracy: 0.6437 - loss: 0.7261 - val_accuracy: 0.6604 - val_loss: 0.5897 - learning_rate: 1.0000e-05
# Epoch 4/15
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.6732 - loss: 0.6600
# Epoch 4: val_loss improved from 0.58968 to 0.57915, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 89s 666ms/step - accuracy: 0.6733 - loss: 0.6599 - val_accuracy: 0.6717 - val_loss: 0.5791 - learning_rate: 1.0000e-05
# Epoch 5/15
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.6933 - loss: 0.6254
# Epoch 5: val_loss improved from 0.57915 to 0.52433, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 88s 659ms/step - accuracy: 0.6934 - loss: 0.6252 - val_accuracy: 0.7208 - val_loss: 0.5243 - learning_rate: 1.0000e-05
# Epoch 6/15
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.7338 - loss: 0.5505
# Epoch 6: val_loss did not improve from 0.52433
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 80s 601ms/step - accuracy: 0.7338 - loss: 0.5504 - val_accuracy: 0.7170 - val_loss: 0.5292 - learning_rate: 1.0000e-05
# Epoch 7/15
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.7570 - loss: 0.5094
# Epoch 7: val_loss did not improve from 0.52433
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 82s 613ms/step - accuracy: 0.7570 - loss: 0.5094 - val_accuracy: 0.7321 - val_loss: 0.5268 - learning_rate: 1.0000e-05
# Epoch 8/15
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.7720 - loss: 0.4915
# Epoch 8: val_loss did not improve from 0.52433
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 81s 607ms/step - accuracy: 0.7721 - loss: 0.4912 - val_accuracy: 0.7509 - val_loss: 0.5374 - learning_rate: 1.0000e-05
# Epoch 9/15
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.8088 - loss: 0.4217
# Epoch 9: val_loss did not improve from 0.52433
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 83s 624ms/step - accuracy: 0.8088 - loss: 0.4216 - val_accuracy: 0.7321 - val_loss: 0.5631 - learning_rate: 2.0000e-06
# Epoch 10/15
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.8089 - loss: 0.4245
# Epoch 10: val_loss did not improve from 0.52433
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/conda/lib/python3.10/site-packages/tensorflow/python/ops/gen_array_ops.py in ?(indices, depth, on_value, off_value, axis, name)
#    6563   if tld.is_eager:
#    6564     try:
# -> 6565       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    6566         _ctx, "OneHot", name, indices, depth, on_value, off_value, "axis",
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1447/634251240.py in ?()
# ----> 1 history = model.fit(
#       2     train_generator,
#       3     epochs=15,
#       4     validation_data=validation_generator,
#
# /opt/conda/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# /opt/conda/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py in ?(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     366                     "val_" + name: val for name, val in val_logs.items()
#     367                 }
#     368                 epoch_logs.update(val_logs)
#     369
# --> 370             callbacks.on_epoch_end(epoch, epoch_logs)
#     371             training_logs = epoch_logs
#     372             if self.stop_training:
#     373                 break
#
# /opt/conda/lib/python3.10/site-packages/keras/src/callbacks/callback_list.py in ?(self, epoch, logs)
#      93     def on_epoch_end(self, epoch, logs=None):
#      94         logs = logs or {}
#      95         for callback in self.callbacks:
# ---> 96             callback.on_epoch_end(epoch, logs)
#
# /opt/conda/lib/python3.10/site-packages/keras/src/callbacks/tensorboard.py in ?(self, epoch, logs)
#     473         """Runs metrics and histogram summaries at epoch end."""
#     474         self._log_epoch_metrics(epoch, logs)
#     475
#     476         if self.histogram_freq and epoch % self.histogram_freq == 0:
# --> 477             self._log_weights(epoch)
#     478
#     479         if self.embeddings_freq and epoch % self.embeddings_freq == 0:
#     480             self._log_embeddings(epoch)
#
# /opt/conda/lib/python3.10/site-packages/keras/src/callbacks/tensorboard.py in ?(self, epoch)
#     550                 for weight in layer.weights:
#     551                     weight_name = weight.name.replace(":", "_")
#     552                     # Add a suffix to prevent summary tag name collision.
#     553                     histogram_weight_name = weight_name + "/histogram"
# --> 554                     self.summary.histogram(
#     555                         histogram_weight_name, weight, step=epoch
#     556                     )
#     557                     if self.write_images:
#
# /opt/conda/lib/python3.10/site-packages/tensorboard/plugins/histogram/summary_v2.py in ?(name, data, step, buckets, description)
#     192         @lazy_tensor_creator.LazyTensorCreator
#     193         def lazy_tensor():
#     194             return _buckets(data, buckets)
#     195
# --> 196         return tf.summary.write(
#     197             tag=tag,
#     198             tensor=lazy_tensor,
#     199             step=step,
#
# /opt/conda/lib/python3.10/site-packages/tensorflow/python/ops/summary_ops_v2.py in ?(tag, tensor, step, metadata, name)
#     798         )
#     799         with ops.control_dependencies([write_summary_op]):
#     800           return constant_op.constant(True)
#     801
# --> 802     op = smart_cond.smart_cond(
#     803         should_record_summaries(), record, _nothing, name="summary_cond")
#     804     if not context.executing_eagerly():
#     805       ops.add_to_collection(ops.GraphKeys._SUMMARY_COLLECTION, op)  # pylint: disable=protected-access
#
# /opt/conda/lib/python3.10/site-packages/tensorflow/python/framework/smart_cond.py in ?(pred, true_fn, false_fn, name)
#      49
#      50   pred_value = smart_constant_value(pred)
#      51   if pred_value is not None:
#      52     if pred_value:
# ---> 53       return true_fn()
#      54     else:
#      55       return false_fn()
#      56   else:
#
# /opt/conda/lib/python3.10/site-packages/tensorflow/python/ops/summary_ops_v2.py in ?()
#     778                          "tf.summary.experimental.set_step()")
#     779
#     780       # Note the identity to move the tensor to the CPU.
#     781       with ops.device("cpu:0"):
# --> 782         summary_tensor = tensor() if callable(tensor) else array_ops.identity(
#     783             tensor)
#     784         # For DTensor, the device scope above doesn't work, we need to
#     785         # explicitly copy the resource tensor to host mesh, which is a cpu
#
# /opt/conda/lib/python3.10/site-packages/tensorboard/util/lazy_tensor_creator.py in ?(self)
#      62                         "Cannot use LazyTensorCreator with reentrant callable"
#      63                     )
#      64                 elif self._tensor is None:
#      65                     self._tensor = _CALL_IN_PROGRESS_SENTINEL
# ---> 66                     self._tensor = self._tensor_callable()
#      67         return self._tensor
#
# /opt/conda/lib/python3.10/site-packages/tensorboard/plugins/histogram/summary_v2.py in ?()
#     192         @lazy_tensor_creator.LazyTensorCreator
#     193         def lazy_tensor():
# --> 194             return _buckets(data, buckets)
#
# /opt/conda/lib/python3.10/site-packages/tensorboard/plugins/histogram/summary_v2.py in ?(data, bucket_count)
#     289             return tf.cond(
#     290                 has_single_value, when_single_value, when_multiple_values
#     291             )
#     292
# --> 293         return tf.cond(is_empty, when_empty, when_nonempty)
#
# /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# /opt/conda/lib/python3.10/site-packages/tensorflow/python/ops/cond.py in ?(pred, true_fn, false_fn, name)
#     339   >>> r.numpy()
#     340   14
#     341
#     342   """
# --> 343   return cond(pred, true_fn=true_fn, false_fn=false_fn, strict=True, name=name)
#
# /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py in ?(*args, **kwargs)
#     584                 _call_location(), decorator_utils.get_qualified_name(func),
#     585                 func.__module__, arg_name,
#     586                 'in a future version' if date is None else ('after %s' % date),
#     587                 instructions)
# --> 588       return func(*args, **kwargs)
#
# /opt/conda/lib/python3.10/site-packages/tensorflow/python/ops/cond.py in ?(pred, true_fn, false_fn, strict, name, fn1, fn2)
#     138   if not callable(false_fn):
#     139     raise TypeError("'false_fn' must be callable.")
#     140
#     141   if context.executing_eagerly():
# --> 142     return _eager_cond_implementation(pred, true_fn, false_fn, strict, name)
#     143
#     144   # Always enable control flow v2 if building a function, regardless of toggle.
#     145   if util.EnableControlFlowV2(ops.get_default_graph()):
#
# /opt/conda/lib/python3.10/site-packages/tensorflow/python/ops/cond.py in ?(pred, true_fn, false_fn, strict, name)
#     383     with ops.name_scope(name, "cond", [pred]):
#     384       if pred_constant_value:
#     385         result = true_fn()
#     386       else:
# --> 387         result = false_fn()
#     388       if not strict:
#     389         result = _UnpackIfSingleton(result)
#     390       return result
#
# /opt/conda/lib/python3.10/site-packages/tensorboard/plugins/histogram/summary_v2.py in ?()
#     285                     dtype=tf.float64,
#     286                 )
#     287                 return tf.transpose(a=tf.stack([edges, edges, bucket_counts]))
#     288
# --> 289             return tf.cond(
#     290                 has_single_value, when_single_value, when_multiple_values
#     291             )
#
# /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# /opt/conda/lib/python3.10/site-packages/tensorflow/python/ops/cond.py in ?(pred, true_fn, false_fn, name)
#     339   >>> r.numpy()
#     340   14
#     341
#     342   """
# --> 343   return cond(pred, true_fn=true_fn, false_fn=false_fn, strict=True, name=name)
#
# /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py in ?(*args, **kwargs)
#     584                 _call_location(), decorator_utils.get_qualified_name(func),
#     585                 func.__module__, arg_name,
#     586                 'in a future version' if date is None else ('after %s' % date),
#     587                 instructions)
# --> 588       return func(*args, **kwargs)
#
# /opt/conda/lib/python3.10/site-packages/tensorflow/python/ops/cond.py in ?(pred, true_fn, false_fn, strict, name, fn1, fn2)
#     138   if not callable(false_fn):
#     139     raise TypeError("'false_fn' must be callable.")
#     140
#     141   if context.executing_eagerly():
# --> 142     return _eager_cond_implementation(pred, true_fn, false_fn, strict, name)
#     143
#     144   # Always enable control flow v2 if building a function, regardless of toggle.
#     145   if util.EnableControlFlowV2(ops.get_default_graph()):
#
# /opt/conda/lib/python3.10/site-packages/tensorflow/python/ops/cond.py in ?(pred, true_fn, false_fn, strict, name)
#     383     with ops.name_scope(name, "cond", [pred]):
#     384       if pred_constant_value:
#     385         result = true_fn()
#     386       else:
# --> 387         result = false_fn()
#     388       if not strict:
#     389         result = _UnpackIfSingleton(result)
#     390       return result
#
# /opt/conda/lib/python3.10/site-packages/tensorboard/plugins/histogram/summary_v2.py in ?()
#     254                 clamped_indices = tf.minimum(bucket_indices, bucket_count - 1)
#     255                 # Use float64 instead of float32 to avoid accumulating floating point error
#     256                 # later in tf.reduce_sum when summing more than 2^24 individual `1.0` values.
#     257                 # See https://github.com/tensorflow/tensorflow/issues/51419 for details.
# --> 258                 one_hots = tf.one_hot(
#     259                     clamped_indices, depth=bucket_count, dtype=tf.float64
#     260                 )
#     261                 bucket_counts = tf.cast(
#
# /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# /opt/conda/lib/python3.10/site-packages/tensorflow/python/ops/array_ops.py in ?(indices, depth, on_value, off_value, axis, dtype, name)
#    4389     if on_dtype != off_dtype:
#    4390       raise TypeError("dtype {0} of on_value does not match "
#    4391                       "dtype {1} of off_value".format(on_dtype, off_dtype))
#    4392
# -> 4393     return gen_array_ops.one_hot(indices, depth, on_value, off_value, axis,
#    4394                                  name)
#
# /opt/conda/lib/python3.10/site-packages/tensorflow/python/ops/gen_array_ops.py in ?(indices, depth, on_value, off_value, axis, name)
#    6561   _ctx = _context._context or _context.context()
#    6562   tld = _ctx._thread_local_data
#    6563   if tld.is_eager:
#    6564     try:
# -> 6565       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    6566         _ctx, "OneHot", name, indices, depth, on_value, off_value, "axis",
#    6567         axis)
#    6568       return _result
#
# KeyboardInterrupt:

# %%
max_loss_threshold = 2.0
min_accuracy_threshold = 0.8

filtered_train_loss = [v for v in history.history['loss'] if v <= max_loss_threshold]
filtered_val_loss = [v for v in history.history['val_loss'] if v <= max_loss_threshold]

filtered_train_accuracy = [v for v in history.history['accuracy'] if v >= min_accuracy_threshold]
filtered_val_accuracy = [v for v in history.history['val_accuracy'] if v >= min_accuracy_threshold]

min_len = min(len(filtered_train_loss), len(filtered_val_loss), len(filtered_train_accuracy), len(filtered_val_accuracy))
filtered_train_loss = filtered_train_loss[:min_len]
filtered_val_loss = filtered_val_loss[:min_len]
filtered_train_accuracy = filtered_train_accuracy[:min_len]
filtered_val_accuracy = filtered_val_accuracy[:min_len]

plt.figure(figsize=(10, 5))
plt.plot(filtered_train_loss, label='Training Loss')
plt.plot(filtered_val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(filtered_train_accuracy, label='Training Accuracy')
plt.plot(filtered_val_accuracy, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %%
model.load_weights('best_model.keras')

test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%')
