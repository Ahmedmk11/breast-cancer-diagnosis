# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, losses
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet101, ResNet50, ResNet152, InceptionV3
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard, ReduceLROnPlateau

import os
import time
import matplotlib.pyplot as plt
import numpy as np
import shutil
import tempfile
# Out:
# 2024-05-17 21:41:23.606114: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-17 21:41:23.606177: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-17 21:41:23.607775: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
dataset_path = '/kaggle/input/stage-2-classification-v2/Stage 2 Classification'

# %%
temp_dir = tempfile.mkdtemp()

class_names = os.listdir(dataset_path)

os.makedirs(temp_dir + '/train')
os.makedirs(temp_dir + '/val')
os.makedirs(temp_dir + '/test')

for class_name in class_names:
    os.makedirs(temp_dir + '/train/' + class_name)
    os.makedirs(temp_dir + '/val/' + class_name)
    os.makedirs(temp_dir + '/test/' + class_name)
    
    image_names = os.listdir(dataset_path + '/' + class_name)
    np.random.shuffle(image_names)
    
    train_names = image_names[:int(len(image_names)*0.8)]
    val_names = image_names[int(len(image_names)*0.8):int(len(image_names)*0.9)]
    test_names = image_names[int(len(image_names)*0.9):]

    for name in train_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/train/' + class_name + '/' + name)
    for name in val_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/val/' + class_name + '/' + name)
    for name in test_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/test/' + class_name + '/' + name)

datagen = ImageDataGenerator(rescale=1./255)

train_generator = datagen.flow_from_directory(
    temp_dir + '/train',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')

validation_generator = datagen.flow_from_directory(
    temp_dir + '/val',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')

test_generator = datagen.flow_from_directory(
    temp_dir + '/test',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')
# Out:
# Found 1967 images belonging to 2 classes.
# Found 246 images belonging to 2 classes.
# Found 247 images belonging to 2 classes.

# %%
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))

model = models.Sequential()
model.add(base_model)
model.add(layers.Flatten())

model.add(layers.Dense(512))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.5))

model.add(layers.Dense(256))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.5))

model.add(layers.Dense(1, activation='sigmoid'))

optimizer = optimizers.Nadam(learning_rate=0.001, use_ema=True, ema_momentum=0.9)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6, verbose=1)
model.compile(loss=losses.BinaryCrossentropy(),
              optimizer=optimizer,
              metrics=['accuracy'])

model.build(input_shape=(None, 299, 299, 3))

# %%
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', mode='min', save_best_only=True, verbose=1)
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, restore_best_weights=True)

log_dir = "/kaggle/working/logs/fit"
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=True)

# %%
history = model.fit(
    train_generator,
    epochs=30,
    validation_data=validation_generator,
    callbacks=[checkpoint, earlystop, tensorboard_callback, reduce_lr]
)
# Out:
# Epoch 1/30
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1715982227.364887     350 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 653ms/step - accuracy: 0.5127 - loss: 0.8408
# Epoch 1: val_loss improved from inf to 5440.99561, saving model to best_model.keras
# W0000 00:00:1715982323.964161     350 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 251s 1s/step - accuracy: 0.5126 - loss: 0.8407 - val_accuracy: 0.4919 - val_loss: 5440.9956 - learning_rate: 0.0010
# Epoch 2/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.4759 - loss: 0.7832
# Epoch 2: val_loss improved from 5440.99561 to 1.17901, saving model to best_model.keras
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 56s 456ms/step - accuracy: 0.4759 - loss: 0.7833 - val_accuracy: 0.5041 - val_loss: 1.1790 - learning_rate: 0.0010
# Epoch 3/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.5289 - loss: 0.7503
# Epoch 3: val_loss improved from 1.17901 to 0.69898, saving model to best_model.keras
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 57s 457ms/step - accuracy: 0.5287 - loss: 0.7503 - val_accuracy: 0.5081 - val_loss: 0.6990 - learning_rate: 0.0010
# Epoch 4/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.5143 - loss: 0.7520
# Epoch 4: val_loss did not improve from 0.69898
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 49s 396ms/step - accuracy: 0.5143 - loss: 0.7519 - val_accuracy: 0.4350 - val_loss: 128.9347 - learning_rate: 0.0010
# Epoch 5/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.4959 - loss: 0.7447
# Epoch 5: val_loss improved from 0.69898 to 0.69392, saving model to best_model.keras
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 56s 449ms/step - accuracy: 0.4960 - loss: 0.7447 - val_accuracy: 0.5041 - val_loss: 0.6939 - learning_rate: 0.0010
# Epoch 6/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.5254 - loss: 0.7442
# Epoch 6: val_loss did not improve from 0.69392
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 49s 393ms/step - accuracy: 0.5254 - loss: 0.7442 - val_accuracy: 0.4756 - val_loss: 27.0894 - learning_rate: 0.0010
# Epoch 7/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.5158 - loss: 0.7361
# Epoch 7: val_loss did not improve from 0.69392
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 49s 394ms/step - accuracy: 0.5156 - loss: 0.7361 - val_accuracy: 0.5325 - val_loss: 2.3909 - learning_rate: 0.0010
# Epoch 8/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.5094 - loss: 0.7242
# Epoch 8: val_loss did not improve from 0.69392
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 49s 393ms/step - accuracy: 0.5094 - loss: 0.7242 - val_accuracy: 0.4878 - val_loss: 1.6306 - learning_rate: 0.0010
# Epoch 9/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.4747 - loss: 0.7260
# Epoch 9: val_loss improved from 0.69392 to 0.69285, saving model to best_model.keras
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 56s 453ms/step - accuracy: 0.4748 - loss: 0.7260 - val_accuracy: 0.5081 - val_loss: 0.6929 - learning_rate: 2.0000e-04
# Epoch 10/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.5190 - loss: 0.7288
# Epoch 10: val_loss did not improve from 0.69285
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 49s 395ms/step - accuracy: 0.5189 - loss: 0.7287 - val_accuracy: 0.4959 - val_loss: 0.7013 - learning_rate: 2.0000e-04
# Epoch 11/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.5383 - loss: 0.7050
# Epoch 11: val_loss did not improve from 0.69285
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 49s 395ms/step - accuracy: 0.5383 - loss: 0.7051 - val_accuracy: 0.5081 - val_loss: 0.6973 - learning_rate: 2.0000e-04
# Epoch 12/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.5108 - loss: 0.7144
# Epoch 12: val_loss did not improve from 0.69285
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 50s 401ms/step - accuracy: 0.5108 - loss: 0.7144 - val_accuracy: 0.4959 - val_loss: 0.6934 - learning_rate: 2.0000e-04
# Epoch 13/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.4938 - loss: 0.7199
# Epoch 13: val_loss improved from 0.69285 to 0.69161, saving model to best_model.keras
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 57s 458ms/step - accuracy: 0.4938 - loss: 0.7199 - val_accuracy: 0.4959 - val_loss: 0.6916 - learning_rate: 4.0000e-05
# Epoch 14/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.4992 - loss: 0.7009
# Epoch 14: val_loss did not improve from 0.69161
# KeyboardInterrupt

# %%
max_loss_threshold = 2.0
min_accuracy_threshold = 0.8

filtered_train_loss = [v for v in history.history['loss'] if v <= max_loss_threshold]
filtered_val_loss = [v for v in history.history['val_loss'] if v <= max_loss_threshold]

filtered_train_accuracy = [v for v in history.history['accuracy'] if v >= min_accuracy_threshold]
filtered_val_accuracy = [v for v in history.history['val_accuracy'] if v >= min_accuracy_threshold]

min_len = min(len(filtered_train_loss), len(filtered_val_loss), len(filtered_train_accuracy), len(filtered_val_accuracy))
filtered_train_loss = filtered_train_loss[:min_len]
filtered_val_loss = filtered_val_loss[:min_len]
filtered_train_accuracy = filtered_train_accuracy[:min_len]
filtered_val_accuracy = filtered_val_accuracy[:min_len]

plt.figure(figsize=(10, 5))
plt.plot(filtered_train_loss, label='Training Loss')
plt.plot(filtered_val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(filtered_train_accuracy, label='Training Accuracy')
plt.plot(filtered_val_accuracy, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %%
model.load_weights('best_model.keras')

test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%')
