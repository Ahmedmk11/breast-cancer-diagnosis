# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, losses
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet101, ResNet50, ResNet152, InceptionV3
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard, ReduceLROnPlateau

import os
import time
import matplotlib.pyplot as plt
import numpy as np
import shutil
import tempfile
# Out:
# 2024-05-17 21:02:22.446290: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-17 21:02:22.446409: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-17 21:02:22.573440: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
dataset_path = '/kaggle/input/stage-2-classification-v2/Stage 2 Classification'

# %%
temp_dir = tempfile.mkdtemp()

class_names = os.listdir(dataset_path)

os.makedirs(temp_dir + '/train')
os.makedirs(temp_dir + '/val')
os.makedirs(temp_dir + '/test')

for class_name in class_names:
    os.makedirs(temp_dir + '/train/' + class_name)
    os.makedirs(temp_dir + '/val/' + class_name)
    os.makedirs(temp_dir + '/test/' + class_name)
    
    image_names = os.listdir(dataset_path + '/' + class_name)
    np.random.shuffle(image_names)
    
    train_names = image_names[:int(len(image_names)*0.8)]
    val_names = image_names[int(len(image_names)*0.8):int(len(image_names)*0.9)]
    test_names = image_names[int(len(image_names)*0.9):]

    for name in train_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/train/' + class_name + '/' + name)
    for name in val_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/val/' + class_name + '/' + name)
    for name in test_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/test/' + class_name + '/' + name)

datagen = ImageDataGenerator(rescale=1./255)

train_generator = datagen.flow_from_directory(
    temp_dir + '/train',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')

validation_generator = datagen.flow_from_directory(
    temp_dir + '/val',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')

test_generator = datagen.flow_from_directory(
    temp_dir + '/test',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')
# Out:
# Found 1967 images belonging to 2 classes.
# Found 246 images belonging to 2 classes.
# Found 247 images belonging to 2 classes.

# %%
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))

model = models.Sequential()
model.add(base_model)
model.add(layers.Flatten())

model.add(layers.Dense(512))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.5))

model.add(layers.Dense(256))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.5))

model.add(layers.Dense(1, activation='sigmoid'))

optimizer = optimizers.AdamW(learning_rate=0.0001)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6, verbose=1)
model.compile(loss=losses.BinaryCrossentropy(),
              optimizer=optimizer,
              metrics=['accuracy'])

model.build(input_shape=(None, 299, 299, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', mode='min', save_best_only=True, verbose=1)
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, restore_best_weights=True)

log_dir = "/kaggle/working/logs/fit"
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=True)

# %%
history = model.fit(
    train_generator,
    epochs=30,
    validation_data=validation_generator,
    callbacks=[checkpoint, earlystop, tensorboard_callback, reduce_lr]
)
# Out:
# Epoch 1/30
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1715979882.099152     122 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1715979882.219089     122 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 664ms/step - accuracy: 0.5689 - loss: 0.8119
# W0000 00:00:1715979971.250933     122 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_loss improved from inf to 0.55475, saving model to best_model.keras
# W0000 00:00:1715979981.020653     121 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 240s 1s/step - accuracy: 0.5693 - loss: 0.8114 - val_accuracy: 0.7358 - val_loss: 0.5548 - learning_rate: 1.0000e-04
# Epoch 2/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.7793 - loss: 0.4732
# Epoch 2: val_loss improved from 0.55475 to 0.50524, saving model to best_model.keras
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 58s 466ms/step - accuracy: 0.7793 - loss: 0.4733 - val_accuracy: 0.8089 - val_loss: 0.5052 - learning_rate: 1.0000e-04
# Epoch 3/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8699 - loss: 0.3058
# Epoch 3: val_loss did not improve from 0.50524
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 49s 390ms/step - accuracy: 0.8700 - loss: 0.3057 - val_accuracy: 0.7520 - val_loss: 0.6192 - learning_rate: 1.0000e-04
# Epoch 4/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9339 - loss: 0.1743
# Epoch 4: val_loss did not improve from 0.50524
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 48s 390ms/step - accuracy: 0.9339 - loss: 0.1742 - val_accuracy: 0.8008 - val_loss: 0.5229 - learning_rate: 1.0000e-04
# Epoch 5/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9579 - loss: 0.1258
# Epoch 5: val_loss improved from 0.50524 to 0.46417, saving model to best_model.keras
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 54s 434ms/step - accuracy: 0.9580 - loss: 0.1257 - val_accuracy: 0.8089 - val_loss: 0.4642 - learning_rate: 1.0000e-04
# Epoch 6/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9683 - loss: 0.0903
# Epoch 6: val_loss did not improve from 0.46417
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 49s 392ms/step - accuracy: 0.9683 - loss: 0.0904 - val_accuracy: 0.8049 - val_loss: 0.5144 - learning_rate: 1.0000e-04
# Epoch 7/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9681 - loss: 0.1026
# Epoch 7: val_loss did not improve from 0.46417
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 48s 387ms/step - accuracy: 0.9681 - loss: 0.1026 - val_accuracy: 0.8333 - val_loss: 0.5188 - learning_rate: 1.0000e-04
# Epoch 8/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9774 - loss: 0.0765
# Epoch 8: val_loss did not improve from 0.46417
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 49s 392ms/step - accuracy: 0.9773 - loss: 0.0767 - val_accuracy: 0.8333 - val_loss: 0.4886 - learning_rate: 1.0000e-04
# Epoch 9/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9719 - loss: 0.0730
# Epoch 9: val_loss improved from 0.46417 to 0.36215, saving model to best_model.keras
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 54s 435ms/step - accuracy: 0.9719 - loss: 0.0730 - val_accuracy: 0.8740 - val_loss: 0.3622 - learning_rate: 2.0000e-05
# Epoch 10/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9921 - loss: 0.0317
# Epoch 10: val_loss improved from 0.36215 to 0.35111, saving model to best_model.keras
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 57s 460ms/step - accuracy: 0.9921 - loss: 0.0317 - val_accuracy: 0.8699 - val_loss: 0.3511 - learning_rate: 2.0000e-05
# Epoch 11/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9966 - loss: 0.0302
# Epoch 11: val_loss did not improve from 0.35111
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 49s 395ms/step - accuracy: 0.9966 - loss: 0.0302 - val_accuracy: 0.8577 - val_loss: 0.3566 - learning_rate: 2.0000e-05
# Epoch 12/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9947 - loss: 0.0229
# Epoch 12: val_loss did not improve from 0.35111
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 49s 391ms/step - accuracy: 0.9947 - loss: 0.0230 - val_accuracy: 0.8740 - val_loss: 0.3514 - learning_rate: 2.0000e-05
# Epoch 13/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9938 - loss: 0.0237
# Epoch 13: val_loss did not improve from 0.35111
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 49s 391ms/step - accuracy: 0.9938 - loss: 0.0237 - val_accuracy: 0.8537 - val_loss: 0.3877 - learning_rate: 2.0000e-05
# Epoch 14/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9956 - loss: 0.0210
# Epoch 14: val_loss did not improve from 0.35111
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 48s 388ms/step - accuracy: 0.9956 - loss: 0.0210 - val_accuracy: 0.8618 - val_loss: 0.3736 - learning_rate: 4.0000e-06
# Epoch 15/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9971 - loss: 0.0177
# Epoch 15: val_loss did not improve from 0.35111
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 48s 386ms/step - accuracy: 0.9971 - loss: 0.0177 - val_accuracy: 0.8618 - val_loss: 0.3677 - learning_rate: 4.0000e-06
# Epoch 16/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9979 - loss: 0.0213
# Epoch 16: val_loss did not improve from 0.35111
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1e-06.
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 48s 388ms/step - accuracy: 0.9979 - loss: 0.0213 - val_accuracy: 0.8618 - val_loss: 0.3741 - learning_rate: 4.0000e-06
# Epoch 17/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9967 - loss: 0.0192
# Epoch 17: val_loss did not improve from 0.35111
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 49s 391ms/step - accuracy: 0.9967 - loss: 0.0192 - val_accuracy: 0.8618 - val_loss: 0.3736 - learning_rate: 1.0000e-06
# Epoch 18/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9964 - loss: 0.0194
# Epoch 18: val_loss did not improve from 0.35111
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 48s 389ms/step - accuracy: 0.9963 - loss: 0.0195 - val_accuracy: 0.8659 - val_loss: 0.3760 - learning_rate: 1.0000e-06
# Epoch 19/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9982 - loss: 0.0170
# Epoch 19: val_loss did not improve from 0.35111
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 49s 392ms/step - accuracy: 0.9982 - loss: 0.0171 - val_accuracy: 0.8618 - val_loss: 0.3740 - learning_rate: 1.0000e-06
# Epoch 20/30
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9994 - loss: 0.0164
# Epoch 20: val_loss did not improve from 0.35111
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 49s 391ms/step - accuracy: 0.9994 - loss: 0.0164 - val_accuracy: 0.8618 - val_loss: 0.3729 - learning_rate: 1.0000e-06
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.

# %%
max_loss_threshold = 2.0
min_accuracy_threshold = 0.8

filtered_train_loss = [v for v in history.history['loss'] if v <= max_loss_threshold]
filtered_val_loss = [v for v in history.history['val_loss'] if v <= max_loss_threshold]

filtered_train_accuracy = [v for v in history.history['accuracy'] if v >= min_accuracy_threshold]
filtered_val_accuracy = [v for v in history.history['val_accuracy'] if v >= min_accuracy_threshold]

min_len = min(len(filtered_train_loss), len(filtered_val_loss), len(filtered_train_accuracy), len(filtered_val_accuracy))
filtered_train_loss = filtered_train_loss[:min_len]
filtered_val_loss = filtered_val_loss[:min_len]
filtered_train_accuracy = filtered_train_accuracy[:min_len]
filtered_val_accuracy = filtered_val_accuracy[:min_len]

plt.figure(figsize=(10, 5))
plt.plot(filtered_train_loss, label='Training Loss')
plt.plot(filtered_val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(filtered_train_accuracy, label='Training Accuracy')
plt.plot(filtered_val_accuracy, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %%
model.load_weights('best_model.keras')

test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%')
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 669ms/step - accuracy: 0.8592 - loss: 0.3784
# Test Loss: 0.4231, Test Accuracy: 0.85%
# W0000 00:00:1715981011.229957     121 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
