# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, losses
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet101, ResNet50, ResNet152, InceptionV3, InceptionResNetV2
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard, ReduceLROnPlateau

import os
import time
import matplotlib.pyplot as plt
import numpy as np
import shutil
import tempfile
# Out:
# 2024-05-18 02:47:52.233916: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-18 02:47:52.233976: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-18 02:47:52.235489: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
dataset_path = '/kaggle/input/stage-2-classification/Stage 2 Classification'

# %%
temp_dir = tempfile.mkdtemp()

class_names = os.listdir(dataset_path)

os.makedirs(temp_dir + '/train')
os.makedirs(temp_dir + '/val')
os.makedirs(temp_dir + '/test')

for class_name in class_names:
    os.makedirs(temp_dir + '/train/' + class_name)
    os.makedirs(temp_dir + '/val/' + class_name)
    os.makedirs(temp_dir + '/test/' + class_name)
    
    image_names = os.listdir(dataset_path + '/' + class_name)
    np.random.shuffle(image_names)
    
    train_names = image_names[:int(len(image_names)*0.8)]
    val_names = image_names[int(len(image_names)*0.8):int(len(image_names)*0.9)]
    test_names = image_names[int(len(image_names)*0.9):]

    for name in train_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/train/' + class_name + '/' + name)
    for name in val_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/val/' + class_name + '/' + name)
    for name in test_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/test/' + class_name + '/' + name)

datagen = ImageDataGenerator(rescale=1./255)

train_generator = datagen.flow_from_directory(
    temp_dir + '/train',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')

validation_generator = datagen.flow_from_directory(
    temp_dir + '/val',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')

test_generator = datagen.flow_from_directory(
    temp_dir + '/test',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')
# Out:
# Found 2119 images belonging to 2 classes.
# Found 265 images belonging to 2 classes.
# Found 265 images belonging to 2 classes.

# %%
base_model = InceptionResNetV2(weights='imagenet', include_top=False, input_shape=(299, 299, 3))

model = models.Sequential()
model.add(base_model)
model.add(layers.Flatten())

model.add(layers.Dense(512))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.7))

model.add(layers.Dense(256))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.7))

model.add(layers.Dense(1, activation='sigmoid'))

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6, verbose=1)
model.compile(loss=losses.BinaryCrossentropy(),
              optimizer=optimizers.AdamW(0.0001),
              metrics=['accuracy'])

model.build(input_shape=(None, 299, 299, 3))

# %%
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', mode='min', save_best_only=True, verbose=1)
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, restore_best_weights=True)

log_dir = "/kaggle/working/logs/fit"
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=True)

# %%
history = model.fit(
    train_generator,
    epochs=30,
    validation_data=validation_generator,
    callbacks=[checkpoint, earlystop, tensorboard_callback, reduce_lr]
)
# Out:
# Epoch 1/30
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1716000705.433804     767 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1716000705.730855     767 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#   5/133 ━━━━━━━━━━━━━━━━━━━━ 55:17 26s/step - accuracy: 0.5533 - loss: 0.8861
# W0000 00:00:1716000811.830999     765 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5549 - loss: 0.9290
# W0000 00:00:1716000866.043222     766 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_loss improved from inf to 0.93955, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 436s 2s/step - accuracy: 0.5552 - loss: 0.9284 - val_accuracy: 0.6113 - val_loss: 0.9396 - learning_rate: 1.0000e-04
# Epoch 2/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.6834 - loss: 0.6454
# Epoch 2: val_loss improved from 0.93955 to 0.64297, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 88s 659ms/step - accuracy: 0.6836 - loss: 0.6454 - val_accuracy: 0.7170 - val_loss: 0.6430 - learning_rate: 1.0000e-04
# Epoch 3/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.8073 - loss: 0.4341
# Epoch 3: val_loss improved from 0.64297 to 0.57098, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 88s 662ms/step - accuracy: 0.8073 - loss: 0.4341 - val_accuracy: 0.7472 - val_loss: 0.5710 - learning_rate: 1.0000e-04
# Epoch 4/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.8650 - loss: 0.3082
# Epoch 4: val_loss did not improve from 0.57098
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 81s 609ms/step - accuracy: 0.8651 - loss: 0.3081 - val_accuracy: 0.7509 - val_loss: 0.6769 - learning_rate: 1.0000e-04
# Epoch 5/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9352 - loss: 0.2088
# Epoch 5: val_loss improved from 0.57098 to 0.47017, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 89s 667ms/step - accuracy: 0.9351 - loss: 0.2087 - val_accuracy: 0.7887 - val_loss: 0.4702 - learning_rate: 1.0000e-04
# Epoch 6/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9520 - loss: 0.1396
# Epoch 6: val_loss did not improve from 0.47017
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 81s 606ms/step - accuracy: 0.9520 - loss: 0.1396 - val_accuracy: 0.7623 - val_loss: 0.5965 - learning_rate: 1.0000e-04
# Epoch 7/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9601 - loss: 0.1141
# Epoch 7: val_loss did not improve from 0.47017
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 80s 601ms/step - accuracy: 0.9601 - loss: 0.1140 - val_accuracy: 0.8189 - val_loss: 0.5050 - learning_rate: 1.0000e-04
# Epoch 8/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9799 - loss: 0.0851
# Epoch 8: val_loss did not improve from 0.47017
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 81s 603ms/step - accuracy: 0.9799 - loss: 0.0851 - val_accuracy: 0.8038 - val_loss: 0.5640 - learning_rate: 1.0000e-04
# Epoch 9/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9844 - loss: 0.0742
# Epoch 9: val_loss improved from 0.47017 to 0.45308, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 88s 657ms/step - accuracy: 0.9844 - loss: 0.0741 - val_accuracy: 0.8453 - val_loss: 0.4531 - learning_rate: 2.0000e-05
# Epoch 10/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9866 - loss: 0.0421
# Epoch 10: val_loss did not improve from 0.45308
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 81s 608ms/step - accuracy: 0.9866 - loss: 0.0421 - val_accuracy: 0.8415 - val_loss: 0.4567 - learning_rate: 2.0000e-05
# Epoch 11/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9830 - loss: 0.0644
# Epoch 11: val_loss did not improve from 0.45308
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 81s 609ms/step - accuracy: 0.9831 - loss: 0.0643 - val_accuracy: 0.8189 - val_loss: 0.5160 - learning_rate: 2.0000e-05
# Epoch 12/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9937 - loss: 0.0345
# Epoch 12: val_loss did not improve from 0.45308
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 82s 612ms/step - accuracy: 0.9937 - loss: 0.0345 - val_accuracy: 0.8340 - val_loss: 0.5699 - learning_rate: 2.0000e-05
# Epoch 13/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9981 - loss: 0.0253
# Epoch 13: val_loss did not improve from 0.45308
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 81s 609ms/step - accuracy: 0.9981 - loss: 0.0253 - val_accuracy: 0.8226 - val_loss: 0.5747 - learning_rate: 4.0000e-06
# Epoch 14/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9929 - loss: 0.0290
# Epoch 14: val_loss did not improve from 0.45308
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 81s 609ms/step - accuracy: 0.9929 - loss: 0.0291 - val_accuracy: 0.8264 - val_loss: 0.5983 - learning_rate: 4.0000e-06
# Epoch 15/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9938 - loss: 0.0372
# Epoch 15: val_loss did not improve from 0.45308
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1e-06.
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 81s 603ms/step - accuracy: 0.9938 - loss: 0.0372 - val_accuracy: 0.8264 - val_loss: 0.5909 - learning_rate: 4.0000e-06
# Epoch 16/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9879 - loss: 0.0456
# Epoch 16: val_loss did not improve from 0.45308
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 81s 603ms/step - accuracy: 0.9879 - loss: 0.0455 - val_accuracy: 0.8226 - val_loss: 0.5931 - learning_rate: 1.0000e-06
# Epoch 17/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9952 - loss: 0.0298
# Epoch 17: val_loss did not improve from 0.45308
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 80s 603ms/step - accuracy: 0.9952 - loss: 0.0297 - val_accuracy: 0.8189 - val_loss: 0.5612 - learning_rate: 1.0000e-06
# Epoch 18/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9969 - loss: 0.0259
# Epoch 18: val_loss did not improve from 0.45308
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 83s 619ms/step - accuracy: 0.9969 - loss: 0.0259 - val_accuracy: 0.8226 - val_loss: 0.5683 - learning_rate: 1.0000e-06
# Epoch 19/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9927 - loss: 0.0326
# Epoch 19: val_loss did not improve from 0.45308
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 83s 618ms/step - accuracy: 0.9927 - loss: 0.0326 - val_accuracy: 0.8075 - val_loss: 0.5520 - learning_rate: 1.0000e-06
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.

# %%
max_loss_threshold = 2.0
min_accuracy_threshold = 0.8

filtered_train_loss = [v for v in history.history['loss'] if v <= max_loss_threshold]
filtered_val_loss = [v for v in history.history['val_loss'] if v <= max_loss_threshold]

filtered_train_accuracy = [v for v in history.history['accuracy'] if v >= min_accuracy_threshold]
filtered_val_accuracy = [v for v in history.history['val_accuracy'] if v >= min_accuracy_threshold]

min_len = min(len(filtered_train_loss), len(filtered_val_loss), len(filtered_train_accuracy), len(filtered_val_accuracy))
filtered_train_loss = filtered_train_loss[:min_len]
filtered_val_loss = filtered_val_loss[:min_len]
filtered_train_accuracy = filtered_train_accuracy[:min_len]
filtered_val_accuracy = filtered_val_accuracy[:min_len]

plt.figure(figsize=(10, 5))
plt.plot(filtered_train_loss, label='Training Loss')
plt.plot(filtered_val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(filtered_train_accuracy, label='Training Accuracy')
plt.plot(filtered_val_accuracy, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %%
model.load_weights('best_model.keras')

test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%')
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 0.8196 - loss: 0.4868
# Test Loss: 0.4497, Test Accuracy: 0.82%
