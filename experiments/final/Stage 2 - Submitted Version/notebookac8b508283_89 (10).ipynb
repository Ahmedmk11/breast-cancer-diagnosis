# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, losses
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet101, ResNet50, ResNet152, InceptionV3
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard, ReduceLROnPlateau

import os
import time
import matplotlib.pyplot as plt
import numpy as np
import shutil
import tempfile
# Out:
# 2024-05-17 23:31:54.296027: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-17 23:31:54.296081: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-17 23:31:54.297622: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
dataset_path = '/kaggle/input/stage-2-classification/Stage 2 Classification'

# %%
temp_dir = tempfile.mkdtemp()

class_names = os.listdir(dataset_path)

os.makedirs(temp_dir + '/train')
os.makedirs(temp_dir + '/val')
os.makedirs(temp_dir + '/test')

for class_name in class_names:
    os.makedirs(temp_dir + '/train/' + class_name)
    os.makedirs(temp_dir + '/val/' + class_name)
    os.makedirs(temp_dir + '/test/' + class_name)
    
    image_names = os.listdir(dataset_path + '/' + class_name)
    np.random.shuffle(image_names)
    
    train_names = image_names[:int(len(image_names)*0.8)]
    val_names = image_names[int(len(image_names)*0.8):int(len(image_names)*0.9)]
    test_names = image_names[int(len(image_names)*0.9):]

    for name in train_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/train/' + class_name + '/' + name)
    for name in val_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/val/' + class_name + '/' + name)
    for name in test_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/test/' + class_name + '/' + name)

datagen = ImageDataGenerator(rescale=1./255)

train_generator = datagen.flow_from_directory(
    temp_dir + '/train',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')

validation_generator = datagen.flow_from_directory(
    temp_dir + '/val',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')

test_generator = datagen.flow_from_directory(
    temp_dir + '/test',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')
# Out:
# Found 2119 images belonging to 2 classes.
# Found 265 images belonging to 2 classes.
# Found 265 images belonging to 2 classes.

# %%
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))

model = models.Sequential()
model.add(base_model)
model.add(layers.Flatten())

model.add(layers.Dense(512))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.5))

model.add(layers.Dense(256))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.5))

model.add(layers.Dense(1, activation='sigmoid'))

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6, verbose=1)
model.compile(loss=losses.BinaryCrossentropy(),
              optimizer=optimizers.AdamW(0.0001),
              metrics=['accuracy'])

model.build(input_shape=(None, 299, 299, 3))

# %%
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', mode='min', save_best_only=True, verbose=1)
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, restore_best_weights=True)

log_dir = "/kaggle/working/logs/fit"
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=True)

# %%
history = model.fit(
    train_generator,
    epochs=30,
    validation_data=validation_generator,
    callbacks=[checkpoint, earlystop, tensorboard_callback, reduce_lr]
)
# Out:
# Epoch 1/30
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1715988826.566233    2389 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 121/133 ━━━━━━━━━━━━━━━━━━━━ 7s 590ms/step - accuracy: 0.5832 - loss: 0.7897
# W0000 00:00:1715988898.459468    2389 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 549ms/step - accuracy: 0.5879 - loss: 0.7830
# Epoch 1: val_loss improved from inf to 0.62145, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 228s 948ms/step - accuracy: 0.5883 - loss: 0.7825 - val_accuracy: 0.6906 - val_loss: 0.6215 - learning_rate: 1.0000e-04
# Epoch 2/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.7856 - loss: 0.4753
# Epoch 2: val_loss improved from 0.62145 to 0.54843, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 58s 434ms/step - accuracy: 0.7855 - loss: 0.4755 - val_accuracy: 0.7509 - val_loss: 0.5484 - learning_rate: 1.0000e-04
# Epoch 3/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.8666 - loss: 0.3197
# Epoch 3: val_loss improved from 0.54843 to 0.46790, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 54s 404ms/step - accuracy: 0.8666 - loss: 0.3198 - val_accuracy: 0.7811 - val_loss: 0.4679 - learning_rate: 1.0000e-04
# Epoch 4/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9005 - loss: 0.2288
# Epoch 4: val_loss improved from 0.46790 to 0.38833, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 54s 403ms/step - accuracy: 0.9007 - loss: 0.2287 - val_accuracy: 0.8415 - val_loss: 0.3883 - learning_rate: 1.0000e-04
# Epoch 5/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9444 - loss: 0.1460
# Epoch 5: val_loss did not improve from 0.38833
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 49s 360ms/step - accuracy: 0.9444 - loss: 0.1461 - val_accuracy: 0.8264 - val_loss: 0.4585 - learning_rate: 1.0000e-04
# Epoch 6/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9670 - loss: 0.1098
# Epoch 6: val_loss did not improve from 0.38833
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 49s 360ms/step - accuracy: 0.9670 - loss: 0.1098 - val_accuracy: 0.8491 - val_loss: 0.4585 - learning_rate: 1.0000e-04
# Epoch 7/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9689 - loss: 0.0958
# Epoch 7: val_loss did not improve from 0.38833
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 49s 363ms/step - accuracy: 0.9688 - loss: 0.0958 - val_accuracy: 0.8453 - val_loss: 0.4081 - learning_rate: 1.0000e-04
# Epoch 8/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9788 - loss: 0.0663
# Epoch 8: val_loss improved from 0.38833 to 0.36095, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 56s 416ms/step - accuracy: 0.9789 - loss: 0.0663 - val_accuracy: 0.8868 - val_loss: 0.3610 - learning_rate: 2.0000e-05
# Epoch 9/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9907 - loss: 0.0411
# Epoch 9: val_loss did not improve from 0.36095
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 48s 361ms/step - accuracy: 0.9907 - loss: 0.0411 - val_accuracy: 0.8792 - val_loss: 0.3720 - learning_rate: 2.0000e-05
# Epoch 10/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9963 - loss: 0.0274
# Epoch 10: val_loss did not improve from 0.36095
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 49s 368ms/step - accuracy: 0.9963 - loss: 0.0275 - val_accuracy: 0.8792 - val_loss: 0.3679 - learning_rate: 2.0000e-05
# Epoch 11/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9896 - loss: 0.0416
# Epoch 11: val_loss improved from 0.36095 to 0.35214, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 54s 403ms/step - accuracy: 0.9896 - loss: 0.0416 - val_accuracy: 0.8868 - val_loss: 0.3521 - learning_rate: 2.0000e-05
# Epoch 12/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9934 - loss: 0.0240
# Epoch 12: val_loss did not improve from 0.35214
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 48s 358ms/step - accuracy: 0.9934 - loss: 0.0240 - val_accuracy: 0.8792 - val_loss: 0.3882 - learning_rate: 2.0000e-05
# Epoch 13/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9967 - loss: 0.0212
# Epoch 13: val_loss did not improve from 0.35214
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 48s 360ms/step - accuracy: 0.9967 - loss: 0.0213 - val_accuracy: 0.8943 - val_loss: 0.3721 - learning_rate: 2.0000e-05
# Epoch 14/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9972 - loss: 0.0209
# Epoch 14: val_loss did not improve from 0.35214
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 48s 359ms/step - accuracy: 0.9972 - loss: 0.0209 - val_accuracy: 0.8906 - val_loss: 0.3754 - learning_rate: 2.0000e-05
# Epoch 15/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9906 - loss: 0.0305
# Epoch 15: val_loss did not improve from 0.35214
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 48s 359ms/step - accuracy: 0.9906 - loss: 0.0304 - val_accuracy: 0.8868 - val_loss: 0.3742 - learning_rate: 4.0000e-06
# Epoch 16/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9986 - loss: 0.0189
# Epoch 16: val_loss did not improve from 0.35214
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 48s 360ms/step - accuracy: 0.9986 - loss: 0.0189 - val_accuracy: 0.8868 - val_loss: 0.3730 - learning_rate: 4.0000e-06
# Epoch 17/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9950 - loss: 0.0232
# Epoch 17: val_loss did not improve from 0.35214
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1e-06.
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 48s 359ms/step - accuracy: 0.9950 - loss: 0.0232 - val_accuracy: 0.8717 - val_loss: 0.3784 - learning_rate: 4.0000e-06
# Epoch 18/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9914 - loss: 0.0273
# Epoch 18: val_loss did not improve from 0.35214
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 48s 359ms/step - accuracy: 0.9914 - loss: 0.0273 - val_accuracy: 0.8679 - val_loss: 0.3766 - learning_rate: 1.0000e-06
# Epoch 19/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9989 - loss: 0.0129
# Epoch 19: val_loss did not improve from 0.35214
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 49s 363ms/step - accuracy: 0.9989 - loss: 0.0129 - val_accuracy: 0.8717 - val_loss: 0.3736 - learning_rate: 1.0000e-06
# Epoch 20/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9960 - loss: 0.0235
# Epoch 20: val_loss did not improve from 0.35214
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 48s 360ms/step - accuracy: 0.9960 - loss: 0.0235 - val_accuracy: 0.8755 - val_loss: 0.3696 - learning_rate: 1.0000e-06
# Epoch 21/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9942 - loss: 0.0264
# Epoch 21: val_loss did not improve from 0.35214
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 48s 358ms/step - accuracy: 0.9943 - loss: 0.0263 - val_accuracy: 0.8755 - val_loss: 0.3694 - learning_rate: 1.0000e-06
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.

# %%
max_loss_threshold = 2.0
min_accuracy_threshold = 0.8

filtered_train_loss = [v for v in history.history['loss'] if v <= max_loss_threshold]
filtered_val_loss = [v for v in history.history['val_loss'] if v <= max_loss_threshold]

filtered_train_accuracy = [v for v in history.history['accuracy'] if v >= min_accuracy_threshold]
filtered_val_accuracy = [v for v in history.history['val_accuracy'] if v >= min_accuracy_threshold]

min_len = min(len(filtered_train_loss), len(filtered_val_loss), len(filtered_train_accuracy), len(filtered_val_accuracy))
filtered_train_loss = filtered_train_loss[:min_len]
filtered_val_loss = filtered_val_loss[:min_len]
filtered_train_accuracy = filtered_train_accuracy[:min_len]
filtered_val_accuracy = filtered_val_accuracy[:min_len]

plt.figure(figsize=(10, 5))
plt.plot(filtered_train_loss, label='Training Loss')
plt.plot(filtered_val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(filtered_train_accuracy, label='Training Accuracy')
plt.plot(filtered_val_accuracy, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %%
model.load_weights('best_model.keras')

test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%')
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 0.8438 - loss: 0.4473
# Test Loss: 0.3804, Test Accuracy: 0.86%
