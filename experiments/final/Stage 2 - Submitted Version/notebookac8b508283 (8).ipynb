# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, losses
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet101, ResNet50, ResNet152, InceptionV3
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard, ReduceLROnPlateau

import os
import time
import matplotlib.pyplot as plt
import numpy as np
import shutil
import tempfile
# Out:
# 2024-05-17 22:43:11.082551: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-17 22:43:11.082599: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-17 22:43:11.084039: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
dataset_path = '/kaggle/input/stage-2-classification/Stage 2 Classification'

# %%
temp_dir = tempfile.mkdtemp()

class_names = os.listdir(dataset_path)

os.makedirs(temp_dir + '/train')
os.makedirs(temp_dir + '/val')
os.makedirs(temp_dir + '/test')

for class_name in class_names:
    os.makedirs(temp_dir + '/train/' + class_name)
    os.makedirs(temp_dir + '/val/' + class_name)
    os.makedirs(temp_dir + '/test/' + class_name)
    
    image_names = os.listdir(dataset_path + '/' + class_name)
    np.random.shuffle(image_names)
    
    train_names = image_names[:int(len(image_names)*0.8)]
    val_names = image_names[int(len(image_names)*0.8):int(len(image_names)*0.9)]
    test_names = image_names[int(len(image_names)*0.9):]

    for name in train_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/train/' + class_name + '/' + name)
    for name in val_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/val/' + class_name + '/' + name)
    for name in test_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/test/' + class_name + '/' + name)

datagen = ImageDataGenerator(rescale=1./255)

train_generator = datagen.flow_from_directory(
    temp_dir + '/train',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')

validation_generator = datagen.flow_from_directory(
    temp_dir + '/val',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')

test_generator = datagen.flow_from_directory(
    temp_dir + '/test',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')
# Out:
# Found 2119 images belonging to 2 classes.
# Found 265 images belonging to 2 classes.
# Found 265 images belonging to 2 classes.

# %%
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))

model = models.Sequential()
model.add(base_model)
model.add(layers.Flatten())

model.add(layers.Dense(512))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.5))

model.add(layers.Dense(256))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.5))

model.add(layers.Dense(1, activation='sigmoid'))

optimizer = optimizers.AdamW(learning_rate=0.001)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6, verbose=1)
model.compile(loss=losses.BinaryCrossentropy(),
              optimizer=optimizer,
              metrics=['accuracy'])

model.build(input_shape=(None, 299, 299, 3))

# %%
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', mode='min', save_best_only=True, verbose=1)
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, restore_best_weights=True)

log_dir = "/kaggle/working/logs/fit"
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=True)

# %%
history = model.fit(
    train_generator,
    epochs=30,
    validation_data=validation_generator,
    callbacks=[checkpoint, earlystop, tensorboard_callback, reduce_lr]
)
# Out:
# Epoch 1/30
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1715985915.916725    1676 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 108/133 ━━━━━━━━━━━━━━━━━━━━ 15s 626ms/step - accuracy: 0.5067 - loss: 0.8504
# W0000 00:00:1715985983.964679    1676 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - accuracy: 0.5088 - loss: 0.8440
# Epoch 1: val_loss improved from inf to 24178.13867, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 227s 955ms/step - accuracy: 0.5089 - loss: 0.8438 - val_accuracy: 0.5132 - val_loss: 24178.1387 - learning_rate: 0.0010
# Epoch 2/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.4975 - loss: 0.7877
# Epoch 2: val_loss improved from 24178.13867 to 215.96484, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 57s 426ms/step - accuracy: 0.4977 - loss: 0.7875 - val_accuracy: 0.5208 - val_loss: 215.9648 - learning_rate: 0.0010
# Epoch 3/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.5138 - loss: 0.7496
# Epoch 3: val_loss improved from 215.96484 to 2.54721, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 57s 429ms/step - accuracy: 0.5137 - loss: 0.7497 - val_accuracy: 0.5132 - val_loss: 2.5472 - learning_rate: 0.0010
# Epoch 4/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.5150 - loss: 0.7490
# Epoch 4: val_loss improved from 2.54721 to 0.69308, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 57s 427ms/step - accuracy: 0.5149 - loss: 0.7491 - val_accuracy: 0.5057 - val_loss: 0.6931 - learning_rate: 0.0010
# Epoch 5/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.4748 - loss: 0.7494
# Epoch 5: val_loss did not improve from 0.69308
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 51s 383ms/step - accuracy: 0.4750 - loss: 0.7494 - val_accuracy: 0.4755 - val_loss: 0.8035 - learning_rate: 0.0010
# Epoch 6/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.4991 - loss: 0.7436
# Epoch 6: val_loss did not improve from 0.69308
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 52s 388ms/step - accuracy: 0.4992 - loss: 0.7436 - val_accuracy: 0.4792 - val_loss: 0.6968 - learning_rate: 0.0010
# Epoch 7/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.4998 - loss: 0.7346
# Epoch 7: val_loss did not improve from 0.69308
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 52s 386ms/step - accuracy: 0.4998 - loss: 0.7346 - val_accuracy: 0.5019 - val_loss: 0.6990 - learning_rate: 0.0010
# Epoch 8/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.5102 - loss: 0.7218
# Epoch 8: val_loss improved from 0.69308 to 0.68745, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 58s 435ms/step - accuracy: 0.5102 - loss: 0.7218 - val_accuracy: 0.5358 - val_loss: 0.6874 - learning_rate: 2.0000e-04
# Epoch 9/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.4928 - loss: 0.7283
# Epoch 9: val_loss did not improve from 0.68745
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 52s 385ms/step - accuracy: 0.4929 - loss: 0.7283 - val_accuracy: 0.5321 - val_loss: 0.7035 - learning_rate: 2.0000e-04
# Epoch 10/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.5299 - loss: 0.7048
# Epoch 10: val_loss did not improve from 0.68745
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 52s 384ms/step - accuracy: 0.5299 - loss: 0.7048 - val_accuracy: 0.5472 - val_loss: 0.7007 - learning_rate: 2.0000e-04
# Epoch 11/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.5532 - loss: 0.7032
# Epoch 11: val_loss did not improve from 0.68745
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 51s 384ms/step - accuracy: 0.5532 - loss: 0.7032 - val_accuracy: 0.5811 - val_loss: 0.6953 - learning_rate: 2.0000e-04
# Epoch 12/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.5844 - loss: 0.6779
# Epoch 12: val_loss did not improve from 0.68745
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 51s 384ms/step - accuracy: 0.5843 - loss: 0.6780 - val_accuracy: 0.5434 - val_loss: 0.6930 - learning_rate: 4.0000e-05
# Epoch 13/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.5717 - loss: 0.6848
# Epoch 13: val_loss did not improve from 0.68745
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 52s 386ms/step - accuracy: 0.5717 - loss: 0.6848 - val_accuracy: 0.5698 - val_loss: 0.6905 - learning_rate: 4.0000e-05
# Epoch 14/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.5628 - loss: 0.6926
# Epoch 14: val_loss improved from 0.68745 to 0.68660, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 57s 428ms/step - accuracy: 0.5628 - loss: 0.6925 - val_accuracy: 0.5547 - val_loss: 0.6866 - learning_rate: 4.0000e-05
# Epoch 15/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.5713 - loss: 0.6855
# Epoch 15: val_loss did not improve from 0.68660
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 52s 385ms/step - accuracy: 0.5714 - loss: 0.6855 - val_accuracy: 0.5547 - val_loss: 0.6868 - learning_rate: 4.0000e-05
# Epoch 16/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.5812 - loss: 0.6958
# Epoch 16: val_loss improved from 0.68660 to 0.68355, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 58s 430ms/step - accuracy: 0.5812 - loss: 0.6958 - val_accuracy: 0.5849 - val_loss: 0.6836 - learning_rate: 4.0000e-05
# Epoch 17/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.5524 - loss: 0.6999
# Epoch 17: val_loss improved from 0.68355 to 0.67470, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 57s 425ms/step - accuracy: 0.5527 - loss: 0.6998 - val_accuracy: 0.5887 - val_loss: 0.6747 - learning_rate: 4.0000e-05
# Epoch 18/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.6077 - loss: 0.6680
# Epoch 18: val_loss improved from 0.67470 to 0.66318, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 57s 426ms/step - accuracy: 0.6078 - loss: 0.6681 - val_accuracy: 0.6075 - val_loss: 0.6632 - learning_rate: 4.0000e-05
# Epoch 19/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.6118 - loss: 0.6664
# Epoch 19: val_loss improved from 0.66318 to 0.65782, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 57s 426ms/step - accuracy: 0.6118 - loss: 0.6663 - val_accuracy: 0.6189 - val_loss: 0.6578 - learning_rate: 4.0000e-05
# Epoch 20/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.6256 - loss: 0.6579
# Epoch 20: val_loss improved from 0.65782 to 0.65573, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 57s 428ms/step - accuracy: 0.6257 - loss: 0.6579 - val_accuracy: 0.6189 - val_loss: 0.6557 - learning_rate: 4.0000e-05
# Epoch 21/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.6234 - loss: 0.6749
# Epoch 21: val_loss improved from 0.65573 to 0.65287, saving model to best_model.keras
# KeyboardInterrupt

# %%
max_loss_threshold = 2.0
min_accuracy_threshold = 0.8

filtered_train_loss = [v for v in history.history['loss'] if v <= max_loss_threshold]
filtered_val_loss = [v for v in history.history['val_loss'] if v <= max_loss_threshold]

filtered_train_accuracy = [v for v in history.history['accuracy'] if v >= min_accuracy_threshold]
filtered_val_accuracy = [v for v in history.history['val_accuracy'] if v >= min_accuracy_threshold]

min_len = min(len(filtered_train_loss), len(filtered_val_loss), len(filtered_train_accuracy), len(filtered_val_accuracy))
filtered_train_loss = filtered_train_loss[:min_len]
filtered_val_loss = filtered_val_loss[:min_len]
filtered_train_accuracy = filtered_train_accuracy[:min_len]
filtered_val_accuracy = filtered_val_accuracy[:min_len]

plt.figure(figsize=(10, 5))
plt.plot(filtered_train_loss, label='Training Loss')
plt.plot(filtered_val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(filtered_train_accuracy, label='Training Accuracy')
plt.plot(filtered_val_accuracy, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %%
model.load_weights('best_model.keras')

test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%')
