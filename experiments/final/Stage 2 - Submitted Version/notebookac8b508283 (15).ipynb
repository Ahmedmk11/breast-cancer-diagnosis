# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, losses
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet101, ResNet50, ResNet152, InceptionV3, InceptionResNetV2
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard, ReduceLROnPlateau

import os
import time
import matplotlib.pyplot as plt
import numpy as np
import shutil
import tempfile
# Out:
# 2024-05-18 03:32:58.775254: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-18 03:32:58.775316: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-18 03:32:58.776917: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
dataset_path = '/kaggle/input/stage-2-classification/Stage 2 Classification'

# %%
temp_dir = tempfile.mkdtemp()

class_names = os.listdir(dataset_path)

os.makedirs(temp_dir + '/train')
os.makedirs(temp_dir + '/val')
os.makedirs(temp_dir + '/test')

for class_name in class_names:
    os.makedirs(temp_dir + '/train/' + class_name)
    os.makedirs(temp_dir + '/val/' + class_name)
    os.makedirs(temp_dir + '/test/' + class_name)
    
    image_names = os.listdir(dataset_path + '/' + class_name)
    np.random.shuffle(image_names)
    
    train_names = image_names[:int(len(image_names)*0.8)]
    val_names = image_names[int(len(image_names)*0.8):int(len(image_names)*0.9)]
    test_names = image_names[int(len(image_names)*0.9):]

    for name in train_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/train/' + class_name + '/' + name)
    for name in val_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/val/' + class_name + '/' + name)
    for name in test_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/test/' + class_name + '/' + name)

datagen = ImageDataGenerator(rescale=1./255)

train_generator = datagen.flow_from_directory(
    temp_dir + '/train',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')

validation_generator = datagen.flow_from_directory(
    temp_dir + '/val',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')

test_generator = datagen.flow_from_directory(
    temp_dir + '/test',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')
# Out:
# Found 2119 images belonging to 2 classes.
# Found 265 images belonging to 2 classes.
# Found 265 images belonging to 2 classes.

# %%
base_model = InceptionResNetV2(weights='imagenet', include_top=False, input_shape=(299, 299, 3))

model = models.Sequential()
model.add(base_model)
model.add(layers.Flatten())

model.add(layers.Dense(512))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.7))

model.add(layers.Dense(256))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.7))

model.add(layers.Dense(1, activation='sigmoid'))

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6, verbose=1)
model.compile(loss=losses.BinaryCrossentropy(),
              optimizer=optimizers.AdamW(0.0001, weight_decay=0.0001),
              metrics=['accuracy'])

model.build(input_shape=(None, 299, 299, 3))

# %%
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', mode='min', save_best_only=True, verbose=1)
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, restore_best_weights=True)

log_dir = "/kaggle/working/logs/fit"
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=True)

# %%
history = model.fit(
    train_generator,
    epochs=30,
    validation_data=validation_generator,
    callbacks=[checkpoint, earlystop, tensorboard_callback, reduce_lr]
)
# Out:
# Epoch 1/30
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1716003413.306901    1185 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1716003413.585292    1185 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#  13/133 ━━━━━━━━━━━━━━━━━━━━ 16:40 8s/step - accuracy: 0.5382 - loss: 0.9440
# W0000 00:00:1716003515.940859    1185 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5293 - loss: 0.9392
# W0000 00:00:1716003566.866724    1186 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_loss improved from inf to 0.66833, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 429s 2s/step - accuracy: 0.5294 - loss: 0.9390 - val_accuracy: 0.6415 - val_loss: 0.6683 - learning_rate: 1.0000e-04
# Epoch 2/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.6643 - loss: 0.7084
# Epoch 2: val_loss did not improve from 0.66833
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 82s 611ms/step - accuracy: 0.6642 - loss: 0.7086 - val_accuracy: 0.6792 - val_loss: 0.7513 - learning_rate: 1.0000e-04
# Epoch 3/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.6940 - loss: 0.6957
# Epoch 3: val_loss improved from 0.66833 to 0.58049, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 89s 664ms/step - accuracy: 0.6943 - loss: 0.6951 - val_accuracy: 0.6943 - val_loss: 0.5805 - learning_rate: 1.0000e-04
# Epoch 4/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.7964 - loss: 0.4586
# Epoch 4: val_loss improved from 0.58049 to 0.55313, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 88s 661ms/step - accuracy: 0.7966 - loss: 0.4583 - val_accuracy: 0.7472 - val_loss: 0.5531 - learning_rate: 1.0000e-04
# Epoch 5/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9075 - loss: 0.2262
# Epoch 5: val_loss improved from 0.55313 to 0.51799, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 88s 661ms/step - accuracy: 0.9074 - loss: 0.2264 - val_accuracy: 0.7849 - val_loss: 0.5180 - learning_rate: 1.0000e-04
# Epoch 6/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9251 - loss: 0.2044
# Epoch 6: val_loss did not improve from 0.51799
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 82s 613ms/step - accuracy: 0.9252 - loss: 0.2043 - val_accuracy: 0.7925 - val_loss: 0.5528 - learning_rate: 1.0000e-04
# Epoch 7/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9668 - loss: 0.1124
# Epoch 7: val_loss did not improve from 0.51799
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 82s 616ms/step - accuracy: 0.9668 - loss: 0.1124 - val_accuracy: 0.8000 - val_loss: 0.5799 - learning_rate: 1.0000e-04
# Epoch 8/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9748 - loss: 0.0887
# Epoch 8: val_loss improved from 0.51799 to 0.51406, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 90s 672ms/step - accuracy: 0.9747 - loss: 0.0888 - val_accuracy: 0.8226 - val_loss: 0.5141 - learning_rate: 1.0000e-04
# Epoch 9/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9817 - loss: 0.0697
# Epoch 9: val_loss did not improve from 0.51406
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 82s 615ms/step - accuracy: 0.9817 - loss: 0.0698 - val_accuracy: 0.8113 - val_loss: 0.5859 - learning_rate: 1.0000e-04
# Epoch 10/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9865 - loss: 0.0499
# Epoch 10: val_loss did not improve from 0.51406
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 141s 609ms/step - accuracy: 0.9864 - loss: 0.0500 - val_accuracy: 0.8113 - val_loss: 0.5639 - learning_rate: 1.0000e-04
# Epoch 11/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9863 - loss: 0.0540
# Epoch 11: val_loss did not improve from 0.51406
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 82s 612ms/step - accuracy: 0.9863 - loss: 0.0541 - val_accuracy: 0.8189 - val_loss: 0.6265 - learning_rate: 1.0000e-04
# Epoch 12/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9815 - loss: 0.0627
# Epoch 12: val_loss did not improve from 0.51406
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 82s 612ms/step - accuracy: 0.9815 - loss: 0.0626 - val_accuracy: 0.8189 - val_loss: 0.5688 - learning_rate: 2.0000e-05
# Epoch 13/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9940 - loss: 0.0279
# Epoch 13: val_loss did not improve from 0.51406
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 82s 614ms/step - accuracy: 0.9940 - loss: 0.0279 - val_accuracy: 0.8302 - val_loss: 0.5672 - learning_rate: 2.0000e-05
# Epoch 14/30
#  70/133 ━━━━━━━━━━━━━━━━━━━━ 20s 321ms/step - accuracy: 0.9973 - loss: 0.0305
# KeyboardInterrupt

# %%
max_loss_threshold = 2.0
min_accuracy_threshold = 0.8

filtered_train_loss = [v for v in history.history['loss'] if v <= max_loss_threshold]
filtered_val_loss = [v for v in history.history['val_loss'] if v <= max_loss_threshold]

filtered_train_accuracy = [v for v in history.history['accuracy'] if v >= min_accuracy_threshold]
filtered_val_accuracy = [v for v in history.history['val_accuracy'] if v >= min_accuracy_threshold]

min_len = min(len(filtered_train_loss), len(filtered_val_loss), len(filtered_train_accuracy), len(filtered_val_accuracy))
filtered_train_loss = filtered_train_loss[:min_len]
filtered_val_loss = filtered_val_loss[:min_len]
filtered_train_accuracy = filtered_train_accuracy[:min_len]
filtered_val_accuracy = filtered_val_accuracy[:min_len]

plt.figure(figsize=(10, 5))
plt.plot(filtered_train_loss, label='Training Loss')
plt.plot(filtered_val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(filtered_train_accuracy, label='Training Accuracy')
plt.plot(filtered_val_accuracy, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %%
model.load_weights('best_model.keras')

test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%')
