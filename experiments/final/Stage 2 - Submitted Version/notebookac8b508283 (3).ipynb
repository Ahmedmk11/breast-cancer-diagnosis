# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, losses
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet101, ResNet50, ResNet152, InceptionV3
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard, ReduceLROnPlateau

import os
import time
import matplotlib.pyplot as plt
import numpy as np
import shutil
import tempfile
# Out:
# 2024-05-17 19:45:49.945495: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-17 19:45:49.945563: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-17 19:45:49.947170: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
dataset_path = '/kaggle/input/stage-2-classification/Stage 2 Classification'

# %%
temp_dir = tempfile.mkdtemp()

class_names = os.listdir(dataset_path)

os.makedirs(temp_dir + '/train')
os.makedirs(temp_dir + '/val')
os.makedirs(temp_dir + '/test')

for class_name in class_names:
    os.makedirs(temp_dir + '/train/' + class_name)
    os.makedirs(temp_dir + '/val/' + class_name)
    os.makedirs(temp_dir + '/test/' + class_name)
    
    image_names = os.listdir(dataset_path + '/' + class_name)
    np.random.shuffle(image_names)
    
    train_names = image_names[:int(len(image_names)*0.8)]
    val_names = image_names[int(len(image_names)*0.8):int(len(image_names)*0.9)]
    test_names = image_names[int(len(image_names)*0.9):]

    for name in train_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/train/' + class_name + '/' + name)
    for name in val_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/val/' + class_name + '/' + name)
    for name in test_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/test/' + class_name + '/' + name)

datagen = ImageDataGenerator(rescale=1./255)

train_generator = datagen.flow_from_directory(
    temp_dir + '/train',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')

validation_generator = datagen.flow_from_directory(
    temp_dir + '/val',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')

test_generator = datagen.flow_from_directory(
    temp_dir + '/test',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')
# Out:
# Found 2119 images belonging to 2 classes.
# Found 265 images belonging to 2 classes.
# Found 265 images belonging to 2 classes.

# %%
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))

model = models.Sequential()
model.add(base_model)
model.add(layers.Flatten())

model.add(layers.Dense(512))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.5))

model.add(layers.Dense(256))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.5))

model.add(layers.Dense(1, activation='sigmoid'))

optimizer = optimizers.AdamW(learning_rate=0.0001, weight_decay=0.01)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6, verbose=1)
model.compile(loss=losses.BinaryCrossentropy(),
              optimizer=optimizer,
              metrics=['accuracy'])

model.build(input_shape=(None, 299, 299, 3))

# %%
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', mode='min', save_best_only=True, verbose=1)
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, restore_best_weights=True)

log_dir = "/kaggle/working/logs/fit"
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=True)

# %%
history = model.fit(
    train_generator,
    epochs=30,
    validation_data=validation_generator,
    callbacks=[checkpoint, earlystop, tensorboard_callback, reduce_lr]
)
# Out:
# Epoch 1/30
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1715975268.576488    3133 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  65/133 ━━━━━━━━━━━━━━━━━━━━ 1:12 1s/step - accuracy: 0.5452 - loss: 0.8504
# W0000 00:00:1715975337.971195    3133 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - accuracy: 0.5854 - loss: 0.7974
# Epoch 1: val_loss improved from inf to 0.80377, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 241s 995ms/step - accuracy: 0.5858 - loss: 0.7970 - val_accuracy: 0.6340 - val_loss: 0.8038 - learning_rate: 1.0000e-04
# Epoch 2/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.7433 - loss: 0.5292
# Epoch 2: val_loss improved from 0.80377 to 0.49384, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 59s 440ms/step - accuracy: 0.7434 - loss: 0.5292 - val_accuracy: 0.7396 - val_loss: 0.4938 - learning_rate: 1.0000e-04
# Epoch 3/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.8484 - loss: 0.3636
# Epoch 3: val_loss did not improve from 0.49384
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 50s 369ms/step - accuracy: 0.8484 - loss: 0.3636 - val_accuracy: 0.7623 - val_loss: 0.5084 - learning_rate: 1.0000e-04
# Epoch 4/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9242 - loss: 0.2057
# Epoch 4: val_loss improved from 0.49384 to 0.49275, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 55s 409ms/step - accuracy: 0.9242 - loss: 0.2057 - val_accuracy: 0.7623 - val_loss: 0.4928 - learning_rate: 1.0000e-04
# Epoch 5/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9493 - loss: 0.1471
# Epoch 5: val_loss improved from 0.49275 to 0.44726, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 55s 410ms/step - accuracy: 0.9492 - loss: 0.1472 - val_accuracy: 0.8151 - val_loss: 0.4473 - learning_rate: 1.0000e-04
# Epoch 6/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9666 - loss: 0.1080
# Epoch 6: val_loss did not improve from 0.44726
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 49s 368ms/step - accuracy: 0.9666 - loss: 0.1080 - val_accuracy: 0.8075 - val_loss: 0.5559 - learning_rate: 1.0000e-04
# Epoch 7/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9548 - loss: 0.1227
# Epoch 7: val_loss did not improve from 0.44726
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 49s 369ms/step - accuracy: 0.9548 - loss: 0.1227 - val_accuracy: 0.7925 - val_loss: 0.5684 - learning_rate: 1.0000e-04
# Epoch 8/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9613 - loss: 0.1177
# Epoch 8: val_loss did not improve from 0.44726
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 50s 372ms/step - accuracy: 0.9613 - loss: 0.1177 - val_accuracy: 0.8302 - val_loss: 0.4696 - learning_rate: 1.0000e-04
# Epoch 9/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9811 - loss: 0.0663
# Epoch 9: val_loss improved from 0.44726 to 0.42540, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 59s 444ms/step - accuracy: 0.9811 - loss: 0.0663 - val_accuracy: 0.8415 - val_loss: 0.4254 - learning_rate: 2.0000e-05
# Epoch 10/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9862 - loss: 0.0484
# Epoch 10: val_loss did not improve from 0.42540
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 50s 371ms/step - accuracy: 0.9862 - loss: 0.0484 - val_accuracy: 0.8377 - val_loss: 0.4517 - learning_rate: 2.0000e-05
# Epoch 11/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9950 - loss: 0.0343
# Epoch 11: val_loss did not improve from 0.42540
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 50s 372ms/step - accuracy: 0.9950 - loss: 0.0343 - val_accuracy: 0.8415 - val_loss: 0.4713 - learning_rate: 2.0000e-05
# Epoch 12/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9905 - loss: 0.0334
# Epoch 12: val_loss did not improve from 0.42540
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 50s 372ms/step - accuracy: 0.9905 - loss: 0.0334 - val_accuracy: 0.8415 - val_loss: 0.4750 - learning_rate: 2.0000e-05
# Epoch 13/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9974 - loss: 0.0218
# Epoch 13: val_loss did not improve from 0.42540
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 50s 372ms/step - accuracy: 0.9974 - loss: 0.0218 - val_accuracy: 0.8453 - val_loss: 0.4619 - learning_rate: 4.0000e-06
# Epoch 14/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9956 - loss: 0.0264
# Epoch 14: val_loss did not improve from 0.42540
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 50s 373ms/step - accuracy: 0.9956 - loss: 0.0264 - val_accuracy: 0.8453 - val_loss: 0.4609 - learning_rate: 4.0000e-06
# Epoch 15/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9954 - loss: 0.0225
# Epoch 15: val_loss did not improve from 0.42540
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1e-06.
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 50s 374ms/step - accuracy: 0.9954 - loss: 0.0225 - val_accuracy: 0.8453 - val_loss: 0.4647 - learning_rate: 4.0000e-06
# Epoch 16/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9977 - loss: 0.0215
# Epoch 16: val_loss did not improve from 0.42540
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 50s 373ms/step - accuracy: 0.9977 - loss: 0.0215 - val_accuracy: 0.8415 - val_loss: 0.4671 - learning_rate: 1.0000e-06
# Epoch 17/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9992 - loss: 0.0181
# Epoch 17: val_loss did not improve from 0.42540
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 51s 377ms/step - accuracy: 0.9992 - loss: 0.0181 - val_accuracy: 0.8415 - val_loss: 0.4695 - learning_rate: 1.0000e-06
# Epoch 18/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9978 - loss: 0.0225
# Epoch 18: val_loss did not improve from 0.42540
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 50s 373ms/step - accuracy: 0.9978 - loss: 0.0225 - val_accuracy: 0.8453 - val_loss: 0.4675 - learning_rate: 1.0000e-06
# Epoch 19/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9969 - loss: 0.0184
# Epoch 19: val_loss did not improve from 0.42540
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 51s 378ms/step - accuracy: 0.9969 - loss: 0.0184 - val_accuracy: 0.8453 - val_loss: 0.4690 - learning_rate: 1.0000e-06
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.

# %%
max_loss_threshold = 2.0
min_accuracy_threshold = 0.8

filtered_train_loss = [v for v in history.history['loss'] if v <= max_loss_threshold]
filtered_val_loss = [v for v in history.history['val_loss'] if v <= max_loss_threshold]

filtered_train_accuracy = [v for v in history.history['accuracy'] if v >= min_accuracy_threshold]
filtered_val_accuracy = [v for v in history.history['val_accuracy'] if v >= min_accuracy_threshold]

min_len = min(len(filtered_train_loss), len(filtered_val_loss), len(filtered_train_accuracy), len(filtered_val_accuracy))
filtered_train_loss = filtered_train_loss[:min_len]
filtered_val_loss = filtered_val_loss[:min_len]
filtered_train_accuracy = filtered_train_accuracy[:min_len]
filtered_val_accuracy = filtered_val_accuracy[:min_len]

plt.figure(figsize=(10, 5))
plt.plot(filtered_train_loss, label='Training Loss')
plt.plot(filtered_val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(filtered_train_accuracy, label='Training Accuracy')
plt.plot(filtered_val_accuracy, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %%
model.load_weights('best_model.keras')

test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%')
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - accuracy: 0.8296 - loss: 0.5006
# Test Loss: 0.5273, Test Accuracy: 0.83%
