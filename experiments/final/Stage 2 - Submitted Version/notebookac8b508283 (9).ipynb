# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, losses
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet101, ResNet50, ResNet152, InceptionV3
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard, ReduceLROnPlateau

import os
import time
import matplotlib.pyplot as plt
import numpy as np
import shutil
import tempfile
# Out:
# 2024-05-17 23:06:01.877120: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-17 23:06:01.877175: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-17 23:06:01.878773: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
dataset_path = '/kaggle/input/stage-2-classification/Stage 2 Classification'

# %%
temp_dir = tempfile.mkdtemp()

class_names = os.listdir(dataset_path)

os.makedirs(temp_dir + '/train')
os.makedirs(temp_dir + '/val')
os.makedirs(temp_dir + '/test')

for class_name in class_names:
    os.makedirs(temp_dir + '/train/' + class_name)
    os.makedirs(temp_dir + '/val/' + class_name)
    os.makedirs(temp_dir + '/test/' + class_name)
    
    image_names = os.listdir(dataset_path + '/' + class_name)
    np.random.shuffle(image_names)
    
    train_names = image_names[:int(len(image_names)*0.8)]
    val_names = image_names[int(len(image_names)*0.8):int(len(image_names)*0.9)]
    test_names = image_names[int(len(image_names)*0.9):]

    for name in train_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/train/' + class_name + '/' + name)
    for name in val_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/val/' + class_name + '/' + name)
    for name in test_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/test/' + class_name + '/' + name)

datagen = ImageDataGenerator(rescale=1./255)

train_generator = datagen.flow_from_directory(
    temp_dir + '/train',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')

validation_generator = datagen.flow_from_directory(
    temp_dir + '/val',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')

test_generator = datagen.flow_from_directory(
    temp_dir + '/test',
    target_size=(299, 299),
    batch_size=16,
    class_mode='binary')
# Out:
# Found 2119 images belonging to 2 classes.
# Found 265 images belonging to 2 classes.
# Found 265 images belonging to 2 classes.

# %%
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))

model = models.Sequential()
model.add(base_model)
model.add(layers.Flatten())

model.add(layers.Dense(512))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.5))

model.add(layers.Dense(256))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.5))

model.add(layers.Dense(1, activation='sigmoid'))

optimizer = optimizers.AdamW(learning_rate=0.0001)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6, verbose=1)
model.compile(loss=losses.BinaryCrossentropy(),
              optimizer=optimizer,
              metrics=['accuracy'])

model.build(input_shape=(None, 299, 299, 3))

# %%
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', mode='min', save_best_only=True, verbose=1)
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, restore_best_weights=True)

log_dir = "/kaggle/working/logs/fit"
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=True)

# %%
history = model.fit(
    train_generator,
    epochs=30,
    validation_data=validation_generator,
    callbacks=[checkpoint, earlystop, tensorboard_callback, reduce_lr]
)
# Out:
# Epoch 1/30
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1715987281.736408    2084 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  11/133 ━━━━━━━━━━━━━━━━━━━━ 10:44 5s/step - accuracy: 0.5237 - loss: 1.0559
# W0000 00:00:1715987335.616125    2082 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - accuracy: 0.5856 - loss: 0.8139
# Epoch 1: val_loss improved from inf to 0.72931, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 224s 937ms/step - accuracy: 0.5859 - loss: 0.8131 - val_accuracy: 0.6642 - val_loss: 0.7293 - learning_rate: 1.0000e-04
# Epoch 2/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.7759 - loss: 0.4684
# Epoch 2: val_loss improved from 0.72931 to 0.50458, saving model to best_model.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 54s 402ms/step - accuracy: 0.7760 - loss: 0.4683 - val_accuracy: 0.7472 - val_loss: 0.5046 - learning_rate: 1.0000e-04
# Epoch 3/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.8922 - loss: 0.2746
# Epoch 3: val_loss did not improve from 0.50458
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 49s 362ms/step - accuracy: 0.8921 - loss: 0.2747 - val_accuracy: 0.7321 - val_loss: 0.5464 - learning_rate: 1.0000e-04
# Epoch 4/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9307 - loss: 0.1738
# Epoch 4: val_loss did not improve from 0.50458
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 49s 362ms/step - accuracy: 0.9308 - loss: 0.1738 - val_accuracy: 0.7660 - val_loss: 0.6026 - learning_rate: 1.0000e-04
# Epoch 5/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9458 - loss: 0.1448
# Epoch 5: val_loss did not improve from 0.50458
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 49s 361ms/step - accuracy: 0.9458 - loss: 0.1447 - val_accuracy: 0.7736 - val_loss: 0.6202 - learning_rate: 1.0000e-04
# Epoch 6/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9769 - loss: 0.0819
# Epoch 6: val_loss did not improve from 0.50458
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 48s 361ms/step - accuracy: 0.9769 - loss: 0.0819 - val_accuracy: 0.8038 - val_loss: 0.5860 - learning_rate: 2.0000e-05
# Epoch 7/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9868 - loss: 0.0540
# Epoch 7: val_loss did not improve from 0.50458
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 49s 363ms/step - accuracy: 0.9868 - loss: 0.0541 - val_accuracy: 0.7962 - val_loss: 0.6006 - learning_rate: 2.0000e-05
# Epoch 8/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9882 - loss: 0.0522
# Epoch 8: val_loss did not improve from 0.50458
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 49s 362ms/step - accuracy: 0.9882 - loss: 0.0522 - val_accuracy: 0.8226 - val_loss: 0.6010 - learning_rate: 2.0000e-05
# Epoch 9/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9893 - loss: 0.0446
# Epoch 9: val_loss did not improve from 0.50458
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 48s 359ms/step - accuracy: 0.9893 - loss: 0.0445 - val_accuracy: 0.8189 - val_loss: 0.5949 - learning_rate: 4.0000e-06
# Epoch 10/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9870 - loss: 0.0530
# Epoch 10: val_loss did not improve from 0.50458
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 49s 361ms/step - accuracy: 0.9870 - loss: 0.0530 - val_accuracy: 0.8189 - val_loss: 0.5983 - learning_rate: 4.0000e-06
# Epoch 11/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9933 - loss: 0.0382
# Epoch 11: val_loss did not improve from 0.50458
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1e-06.
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 49s 363ms/step - accuracy: 0.9933 - loss: 0.0382 - val_accuracy: 0.8151 - val_loss: 0.6004 - learning_rate: 4.0000e-06
# Epoch 12/30
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9934 - loss: 0.0279
# Epoch 12: val_loss did not improve from 0.50458
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 49s 366ms/step - accuracy: 0.9934 - loss: 0.0279 - val_accuracy: 0.8189 - val_loss: 0.6029 - learning_rate: 1.0000e-06
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.

# %%
max_loss_threshold = 2.0
min_accuracy_threshold = 0.8

filtered_train_loss = [v for v in history.history['loss'] if v <= max_loss_threshold]
filtered_val_loss = [v for v in history.history['val_loss'] if v <= max_loss_threshold]

filtered_train_accuracy = [v for v in history.history['accuracy'] if v >= min_accuracy_threshold]
filtered_val_accuracy = [v for v in history.history['val_accuracy'] if v >= min_accuracy_threshold]

min_len = min(len(filtered_train_loss), len(filtered_val_loss), len(filtered_train_accuracy), len(filtered_val_accuracy))
filtered_train_loss = filtered_train_loss[:min_len]
filtered_val_loss = filtered_val_loss[:min_len]
filtered_train_accuracy = filtered_train_accuracy[:min_len]
filtered_val_accuracy = filtered_val_accuracy[:min_len]

plt.figure(figsize=(10, 5))
plt.plot(filtered_train_loss, label='Training Loss')
plt.plot(filtered_val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(filtered_train_accuracy, label='Training Accuracy')
plt.plot(filtered_val_accuracy, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %%
model.load_weights('best_model.keras')

test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%')
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.7251 - loss: 0.5544
# Test Loss: 0.5882, Test Accuracy: 0.71%
