# %% [markdown]
# # Imports

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, losses
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import os
import time
import matplotlib.pyplot as plt
import numpy as np
import shutil
import tempfile
# Out:
# 2024-05-18 14:57:52.107372: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-18 14:57:52.107432: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-18 14:57:52.109119: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
dataset_path = '/kaggle/input/final-version/Stage 1/Stage 1'

# %%
temp_dir = tempfile.mkdtemp()

class_names = os.listdir(dataset_path)

os.makedirs(temp_dir + '/train')
os.makedirs(temp_dir + '/val')
os.makedirs(temp_dir + '/test')

for class_name in class_names:
    os.makedirs(temp_dir + '/train/' + class_name)
    os.makedirs(temp_dir + '/val/' + class_name)
    os.makedirs(temp_dir + '/test/' + class_name)
    
    image_names = os.listdir(dataset_path + '/' + class_name)
    np.random.shuffle(image_names)
    
    train_names = image_names[:int(len(image_names)*0.7)]
    val_names = image_names[int(len(image_names)*0.7):int(len(image_names)*0.85)]
    test_names = image_names[int(len(image_names)*0.85):]

    for name in train_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/train/' + class_name + '/' + name)
    for name in val_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/val/' + class_name + '/' + name)
    for name in test_names:
        shutil.copy(dataset_path + '/' + class_name + '/' + name, temp_dir + '/test/' + class_name + '/' + name)

datagen = ImageDataGenerator(rescale=1./255)

train_generator = datagen.flow_from_directory(
    temp_dir + '/train',
    target_size=(224, 224),
    batch_size=16,
    class_mode='binary')

validation_generator = datagen.flow_from_directory(
    temp_dir + '/val',
    target_size=(224, 224),
    batch_size=16,
    class_mode='binary')

test_generator = datagen.flow_from_directory(
    temp_dir + '/test',
    target_size=(224, 224),
    batch_size=16,
    class_mode='binary')
# Out:
# Found 5751 images belonging to 2 classes.
# Found 1233 images belonging to 2 classes.
# Found 1233 images belonging to 2 classes.

# %%
base_model = ResNet101(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

model = models.Sequential()
model.add(base_model)
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(loss=losses.BinaryCrossentropy(),
              optimizer=optimizers.Adam(learning_rate=0.00001),
              metrics=['accuracy'])

# %%
checkpoint = ModelCheckpoint('best_weights.weights.h5', monitor='val_loss', mode='min', save_best_only=True, verbose=1, save_weights_only=True)
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, restore_best_weights=True)

history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=[checkpoint, earlystop]
)
# Out:
# Epoch 1/50
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1716044529.307106     823 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1716044529.498755     823 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 323/360 ━━━━━━━━━━━━━━━━━━━━ 12s 340ms/step - accuracy: 0.7934 - loss: 0.5878
# W0000 00:00:1716044638.991198     823 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.8027 - loss: 0.5597
# W0000 00:00:1716044653.412019     823 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_loss improved from inf to 2.79201, saving model to best_weights.weights.h5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 273s 382ms/step - accuracy: 0.8029 - loss: 0.5590 - val_accuracy: 0.4826 - val_loss: 2.7920
# Epoch 2/50
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9649 - loss: 0.1013
# Epoch 2: val_loss improved from 2.79201 to 2.69455, saving model to best_weights.weights.h5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 69s 190ms/step - accuracy: 0.9649 - loss: 0.1012 - val_accuracy: 0.5085 - val_loss: 2.6945
# Epoch 3/50
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9837 - loss: 0.0501
# Epoch 3: val_loss improved from 2.69455 to 0.39540, saving model to best_weights.weights.h5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 69s 191ms/step - accuracy: 0.9837 - loss: 0.0501 - val_accuracy: 0.9019 - val_loss: 0.3954
# Epoch 4/50
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9884 - loss: 0.0288
# Epoch 4: val_loss improved from 0.39540 to 0.19517, saving model to best_weights.weights.h5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 82s 190ms/step - accuracy: 0.9884 - loss: 0.0288 - val_accuracy: 0.9538 - val_loss: 0.1952
# Epoch 5/50
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9931 - loss: 0.0182
# Epoch 5: val_loss improved from 0.19517 to 0.02624, saving model to best_weights.weights.h5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 69s 189ms/step - accuracy: 0.9931 - loss: 0.0182 - val_accuracy: 0.9895 - val_loss: 0.0262
# Epoch 6/50
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9960 - loss: 0.0106
# Epoch 6: val_loss did not improve from 0.02624
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 65s 179ms/step - accuracy: 0.9960 - loss: 0.0106 - val_accuracy: 0.9903 - val_loss: 0.0313
# Epoch 7/50
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9959 - loss: 0.0146
# Epoch 7: val_loss improved from 0.02624 to 0.02360, saving model to best_weights.weights.h5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 69s 190ms/step - accuracy: 0.9959 - loss: 0.0146 - val_accuracy: 0.9903 - val_loss: 0.0236
# Epoch 8/50
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9974 - loss: 0.0060
# Epoch 8: val_loss improved from 0.02360 to 0.02252, saving model to best_weights.weights.h5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 69s 190ms/step - accuracy: 0.9974 - loss: 0.0060 - val_accuracy: 0.9919 - val_loss: 0.0225
# Epoch 9/50
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9963 - loss: 0.0073
# Epoch 9: val_loss did not improve from 0.02252
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 65s 179ms/step - accuracy: 0.9963 - loss: 0.0073 - val_accuracy: 0.9919 - val_loss: 0.0235
# Epoch 10/50
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9989 - loss: 0.0046
# Epoch 10: val_loss did not improve from 0.02252
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 65s 179ms/step - accuracy: 0.9989 - loss: 0.0046 - val_accuracy: 0.9919 - val_loss: 0.0326
# Epoch 11/50
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9989 - loss: 0.0026
# Epoch 11: val_loss did not improve from 0.02252
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 65s 179ms/step - accuracy: 0.9989 - loss: 0.0026 - val_accuracy: 0.9927 - val_loss: 0.0270
# Epoch 12/50
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9992 - loss: 0.0034
# Epoch 12: val_loss did not improve from 0.02252
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 65s 179ms/step - accuracy: 0.9992 - loss: 0.0034 - val_accuracy: 0.9903 - val_loss: 0.0401
# Epoch 13/50
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9980 - loss: 0.0095
# Epoch 13: val_loss did not improve from 0.02252
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 65s 179ms/step - accuracy: 0.9980 - loss: 0.0095 - val_accuracy: 0.9919 - val_loss: 0.0347
# Epoch 14/50
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9980 - loss: 0.0083
# Epoch 14: val_loss did not improve from 0.02252
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 65s 180ms/step - accuracy: 0.9980 - loss: 0.0083 - val_accuracy: 0.9878 - val_loss: 0.0464
# Epoch 15/50
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9992 - loss: 0.0020
# Epoch 15: val_loss did not improve from 0.02252
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 65s 179ms/step - accuracy: 0.9992 - loss: 0.0020 - val_accuracy: 0.9919 - val_loss: 0.0366
# Epoch 16/50
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9997 - loss: 0.0014
# Epoch 16: val_loss did not improve from 0.02252
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 65s 179ms/step - accuracy: 0.9997 - loss: 0.0014 - val_accuracy: 0.9895 - val_loss: 0.0456
# Epoch 17/50
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9984 - loss: 0.0044
# Epoch 17: val_loss did not improve from 0.02252
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 65s 179ms/step - accuracy: 0.9984 - loss: 0.0044 - val_accuracy: 0.9886 - val_loss: 0.0525
# Epoch 18/50
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9995 - loss: 9.5987e-04
# Epoch 18: val_loss did not improve from 0.02252
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 65s 178ms/step - accuracy: 0.9995 - loss: 9.6062e-04 - val_accuracy: 0.9935 - val_loss: 0.0442
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.

# %%
max_loss_threshold = 2.0
min_accuracy_threshold = 0.8

filtered_train_loss = [v for v in history.history['loss'] if v <= max_loss_threshold]
filtered_val_loss = [v for v in history.history['val_loss'] if v <= max_loss_threshold]

filtered_train_accuracy = [v for v in history.history['accuracy'] if v >= min_accuracy_threshold]
filtered_val_accuracy = [v for v in history.history['val_accuracy'] if v >= min_accuracy_threshold]

min_len = min(len(filtered_train_loss), len(filtered_val_loss), len(filtered_train_accuracy), len(filtered_val_accuracy))
filtered_train_loss = filtered_train_loss[:min_len]
filtered_val_loss = filtered_val_loss[:min_len]
filtered_train_accuracy = filtered_train_accuracy[:min_len]
filtered_val_accuracy = filtered_val_accuracy[:min_len]

plt.figure(figsize=(10, 5))
plt.plot(filtered_train_loss, label='Training Loss')
plt.plot(filtered_val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(filtered_train_accuracy, label='Training Accuracy')
plt.plot(filtered_val_accuracy, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %%
model.load_weights('best_weights.weights.h5')
print('Loaded')

converter = tf.lite.TFLiteConverter.from_keras_model(model)
print('converter initialized')

tflite_model = converter.convert()
print('converted')

with open('/kaggle/working/model_1.tflite', 'wb') as f:
    f.write(tflite_model)
    print('written')

test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%')
