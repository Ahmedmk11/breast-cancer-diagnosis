# %% [markdown]
# # Imports

# %%
import torch
from torchvision import transforms
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import torch.nn as nn

import timm

from PIL import Image
import os
from contextlib import redirect_stdout
import ssl

import time

import matplotlib.pyplot as plt

ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# # Constants

# %%
dataset_path = '/kaggle/input/final-stage-3-v3/Stage 3 V3'

# %% [markdown]
# # Dataset & Preprocessing

# %%
class ResizeWithPadding:
    def __init__(self, size):
        self.size = size

    def __call__(self, img):
        w, h = img.size
        if h > w:
            new_h = self.size
            new_w = int(w * (self.size / h))
        else:
            new_w = self.size
            new_h = int(h * (self.size / w))
        
        resized_img = img.resize((new_w, new_h), Image.LANCZOS)

        padded_img = Image.new("RGB", (self.size, self.size), color=(0, 0, 0))
        padded_img.paste(resized_img, ((self.size - new_w) // 2, (self.size - new_h) // 2))
        
        return padded_img

transform = transforms.Compose([
    ResizeWithPadding(256),
    transforms.ToTensor(),
])

if os.path.exists(dataset_path + '.DS_Store'):
        os.remove(dataset_path + '.DS_Store')

dataset = datasets.ImageFolder(root=dataset_path, transform=transform)

# %%
total_size = len(dataset)

train_size = int(0.8 * total_size)
val_size = int(0.1 * total_size)
test_size = total_size - train_size - val_size

train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, val_size, test_size])

# %% [markdown]
# # Loading & Modifying ResNet-152 Model

# %%
resnet_model = torch.hub.load('pytorch/vision:v0.10.0', 'resnet101', pretrained=True)

with redirect_stdout(None):
    resnet_model.eval()

num_features = resnet_model.fc.in_features
num_classes = 2

new_fc_layers = [
    torch.nn.Linear(num_features, 512),
    torch.nn.ReLU(),
    torch.nn.Dropout(0.5),
    torch.nn.Linear(512, 256),
    torch.nn.ReLU(),
    torch.nn.Dropout(0.5),
    torch.nn.Linear(256, num_classes)
]
resnet_model.fc = torch.nn.Sequential(*new_fc_layers)
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet101_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# # Loading & Modifying InceptionV4 Model

# %%
inception_model = timm.create_model('inception_v4', pretrained=True)

num_features = inception_model.last_linear.in_features
num_classes = 2

new_fc_layers = nn.Sequential(
    nn.Linear(num_features, 512),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(512, 256),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(256, num_classes)
)

inception_model.last_linear = new_fc_layers

# %% [markdown]
# # Hyperparameters

# %%
num_epochs = 150
batch_size = 8
patience = 15
criterion = torch.nn.CrossEntropyLoss()
resnet_optimizer = torch.optim.AdamW(resnet_model.parameters(), lr=0.0001, weight_decay=1e-4)
inception_optimizer = torch.optim.AdamW(inception_model.parameters(), lr=0.0001, weight_decay=1e-4)
resnet_model = resnet_model.to('cuda')
inception_model = inception_model.to('cuda')

# %% [markdown]
# # Training

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
def train(mod, name, opt):
    best_val_loss = float('inf')
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []
    sensitivities = []
    specificities = []
    
    epochs_no_improve = 0
    early_stop = False

    for epoch in range(num_epochs):
        start_time = time.time()
        mod.train()
        train_loss = 0
        correct_train = 0
        total_train = 0
        true_positives = 0
        true_negatives = 0
        false_positives = 0
        false_negatives = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to('cuda'), labels.to('cuda')
            opt.zero_grad()

            outputs = mod(inputs)
            loss = criterion(outputs, labels)

            loss.backward()
            opt.step()

            train_loss += loss.item()
            _, predicted_train = torch.max(outputs, 1)
            total_train += labels.size(0)
            correct_train += (predicted_train == labels).sum().item()

            true_positives += ((predicted_train == 1) & (labels == 1)).sum().item()
            true_negatives += ((predicted_train == 0) & (labels == 0)).sum().item()
            false_positives += ((predicted_train == 1) & (labels == 0)).sum().item()
            false_negatives += ((predicted_train == 0) & (labels == 1)).sum().item()

        train_loss /= len(train_loader)
        train_accuracy = 100 * correct_train / total_train

        sensitivity = true_positives / (true_positives + false_negatives)
        specificity = true_negatives / (true_negatives + false_positives)

        mod.eval()
        val_loss = 0
        correct_val = 0
        total_val = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to('cuda'), labels.to('cuda')
                outputs = mod(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted_val = torch.max(outputs, 1)
                total_val += labels.size(0)
                correct_val += (predicted_val == labels).sum().item()

        val_loss /= len(val_loader)
        val_accuracy = 100 * correct_val / total_val

        flag = False
        if val_loss < best_val_loss:
            flag = True
            best_val_loss = val_loss
            torch.save(mod.state_dict(), f'best_{name}_model.pth')
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                early_stop = True

        end_time = time.time()
        epoch_time = end_time - start_time

        if flag:
            print(f'Epoch [{epoch+1}/{num_epochs}]: {epoch_time:.2f}s | Saved Model\nTrain Loss: {train_loss:.4f} | Train Accuracy: {train_accuracy:.2f}%\nValidation Loss: {val_loss:.4f} | Validation Accuracy: {val_accuracy:.2f}%')
        else:
            print(f'Epoch [{epoch+1}/{num_epochs}]: {epoch_time:.2f}s\nTrain Loss: {train_loss:.4f} | Train Accuracy: {train_accuracy:.2f}%\nValidation Loss: {val_loss:.4f} | Validation Accuracy: {val_accuracy:.2f}%')
        print('===================================================================================================')

        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_accuracies.append(train_accuracy)
        val_accuracies.append(val_accuracy)
        sensitivities.append(sensitivity)
        specificities.append(specificity)
        
        if early_stop:
            print('========================Early Stopped========================')
            break
        
    return train_losses, val_losses, train_accuracies, val_accuracies, sensitivities, specificities

def plot_graphs(train_losses, val_losses, train_accuracies, val_accuracies, sensitivities, specificities):
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Stage 3: Training and Validation Loss')
    plt.legend()
    plt.show()

    plt.figure(figsize=(10, 5))
    plt.plot(train_accuracies, label='Training Accuracy')
    plt.plot(val_accuracies, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Stage 3: Training and Validation Accuracy')
    plt.legend()
    plt.show()

# %%
inception_train_losses, inception_val_losses, inception_train_accuracies, inception_val_accuracies, inception_sensitivities, inception_specificities = train(inception_model, 'inception', inception_optimizer)
# Out:
# Epoch [1/150]: 36.40s | Saved Model
# Train Loss: 0.4365 | Train Accuracy: 80.43%
# Validation Loss: 0.2917 | Validation Accuracy: 85.71%
# ===================================================================================================
# Epoch [2/150]: 35.58s | Saved Model
# Train Loss: 0.3334 | Train Accuracy: 87.24%
# Validation Loss: 0.2726 | Validation Accuracy: 88.82%
# ===================================================================================================
# Epoch [3/150]: 35.78s | Saved Model
# Train Loss: 0.2490 | Train Accuracy: 90.56%
# Validation Loss: 0.2332 | Validation Accuracy: 92.55%
# ===================================================================================================
# Epoch [4/150]: 35.88s | Saved Model
# Train Loss: 0.2519 | Train Accuracy: 91.80%
# Validation Loss: 0.2146 | Validation Accuracy: 91.30%
# ===================================================================================================
# Epoch [5/150]: 35.67s | Saved Model
# Train Loss: 0.2257 | Train Accuracy: 91.88%
# Validation Loss: 0.2069 | Validation Accuracy: 91.30%
# ===================================================================================================
# Epoch [6/150]: 35.35s
# Train Loss: 0.1527 | Train Accuracy: 94.74%
# Validation Loss: 0.2604 | Validation Accuracy: 90.68%
# ===================================================================================================
# Epoch [7/150]: 35.51s | Saved Model
# Train Loss: 0.1788 | Train Accuracy: 94.59%
# Validation Loss: 0.2022 | Validation Accuracy: 93.17%
# ===================================================================================================
# Epoch [8/150]: 35.37s
# Train Loss: 0.1390 | Train Accuracy: 95.51%
# Validation Loss: 0.4373 | Validation Accuracy: 84.47%
# ===================================================================================================
# Epoch [9/150]: 35.40s
# Train Loss: 0.1358 | Train Accuracy: 96.52%
# Validation Loss: 0.3957 | Validation Accuracy: 89.44%
# ===================================================================================================
# Epoch [10/150]: 35.90s
# Train Loss: 0.1124 | Train Accuracy: 96.21%
# Validation Loss: 0.3738 | Validation Accuracy: 88.82%
# ===================================================================================================
# Epoch [11/150]: 35.48s
# Train Loss: 0.1327 | Train Accuracy: 95.98%
# Validation Loss: 0.2424 | Validation Accuracy: 89.44%
# ===================================================================================================
# Epoch [12/150]: 35.44s
# Train Loss: 0.1289 | Train Accuracy: 95.75%
# Validation Loss: 0.2824 | Validation Accuracy: 89.44%
# ===================================================================================================
# Epoch [13/150]: 35.41s
# Train Loss: 0.1092 | Train Accuracy: 97.06%
# Validation Loss: 0.2394 | Validation Accuracy: 91.93%
# ===================================================================================================
# Epoch [14/150]: 35.62s
# Train Loss: 0.0886 | Train Accuracy: 97.45%
# Validation Loss: 0.3022 | Validation Accuracy: 90.06%
# ===================================================================================================
# Epoch [15/150]: 35.40s
# Train Loss: 0.0842 | Train Accuracy: 96.75%
# Validation Loss: 0.3039 | Validation Accuracy: 90.06%
# ===================================================================================================
# Epoch [16/150]: 35.22s
# Train Loss: 0.0253 | Train Accuracy: 99.54%
# Validation Loss: 0.3512 | Validation Accuracy: 88.82%
# ===================================================================================================
# Epoch [17/150]: 35.42s
# Train Loss: 0.0282 | Train Accuracy: 99.38%
# Validation Loss: 0.3945 | Validation Accuracy: 91.30%
# ===================================================================================================
# Epoch [18/150]: 35.50s
# Train Loss: 0.0735 | Train Accuracy: 97.68%
# Validation Loss: 0.3145 | Validation Accuracy: 84.47%
# ===================================================================================================
# Epoch [19/150]: 35.50s
# Train Loss: 0.0610 | Train Accuracy: 98.45%
# Validation Loss: 0.3057 | Validation Accuracy: 88.20%
# ===================================================================================================
# Epoch [20/150]: 35.87s
# Train Loss: 0.0811 | Train Accuracy: 97.60%
# Validation Loss: 0.4187 | Validation Accuracy: 90.68%
# ===================================================================================================
# Epoch [21/150]: 35.36s
# Train Loss: 0.0553 | Train Accuracy: 98.45%
# Validation Loss: 0.3914 | Validation Accuracy: 88.82%
# ===================================================================================================
# Epoch [22/150]: 35.46s
# Train Loss: 0.0608 | Train Accuracy: 98.38%
# Validation Loss: 0.2526 | Validation Accuracy: 91.30%
# ===================================================================================================
# ========================Early Stopped========================

# %%
plot_graphs(inception_train_losses, inception_val_losses, inception_train_accuracies, inception_val_accuracies, inception_sensitivities, inception_specificities)

# %%
resnet_train_losses, resnet_val_losses, resnet_train_accuracies, resnet_val_accuracies, resnet_sensitivities, resnet_specificities = train(resnet_model, 'resnet', resnet_optimizer)
# Out:
# Epoch [1/150]: 31.69s | Saved Model
# Train Loss: 0.4010 | Train Accuracy: 83.06%
# Validation Loss: 0.2957 | Validation Accuracy: 85.71%
# ===================================================================================================
# Epoch [2/150]: 31.02s
# Train Loss: 0.2594 | Train Accuracy: 89.40%
# Validation Loss: 0.3295 | Validation Accuracy: 89.44%
# ===================================================================================================
# Epoch [3/150]: 31.44s | Saved Model
# Train Loss: 0.2221 | Train Accuracy: 92.03%
# Validation Loss: 0.2502 | Validation Accuracy: 90.68%
# ===================================================================================================
# Epoch [4/150]: 30.83s
# Train Loss: 0.1845 | Train Accuracy: 93.89%
# Validation Loss: 0.2898 | Validation Accuracy: 89.44%
# ===================================================================================================
# Epoch [5/150]: 31.01s
# Train Loss: 0.1456 | Train Accuracy: 95.36%
# Validation Loss: 0.3460 | Validation Accuracy: 87.58%
# ===================================================================================================
# Epoch [6/150]: 30.85s
# Train Loss: 0.1372 | Train Accuracy: 95.67%
# Validation Loss: 0.3697 | Validation Accuracy: 86.96%
# ===================================================================================================
# Epoch [7/150]: 31.16s
# Train Loss: 0.1052 | Train Accuracy: 96.75%
# Validation Loss: 0.2628 | Validation Accuracy: 88.82%
# ===================================================================================================
# Epoch [8/150]: 30.91s
# Train Loss: 0.0956 | Train Accuracy: 96.52%
# Validation Loss: 0.4026 | Validation Accuracy: 87.58%
# ===================================================================================================
# Epoch [9/150]: 31.03s
# Train Loss: 0.0784 | Train Accuracy: 97.60%
# Validation Loss: 0.4428 | Validation Accuracy: 85.71%
# ===================================================================================================
# Epoch [10/150]: 30.89s
# Train Loss: 0.0610 | Train Accuracy: 97.91%
# Validation Loss: 0.3372 | Validation Accuracy: 90.68%
# ===================================================================================================
# Epoch [11/150]: 30.92s
# Train Loss: 0.0389 | Train Accuracy: 98.69%
# Validation Loss: 0.4184 | Validation Accuracy: 88.20%
# ===================================================================================================
# Epoch [12/150]: 30.84s
# Train Loss: 0.0567 | Train Accuracy: 98.30%
# Validation Loss: 0.4955 | Validation Accuracy: 86.34%
# ===================================================================================================
# Epoch [13/150]: 30.95s
# Train Loss: 0.0892 | Train Accuracy: 97.29%
# Validation Loss: 0.6012 | Validation Accuracy: 88.82%
# ===================================================================================================
# Epoch [14/150]: 30.89s
# Train Loss: 0.0760 | Train Accuracy: 97.68%
# Validation Loss: 0.3372 | Validation Accuracy: 88.82%
# ===================================================================================================
# Epoch [15/150]: 30.99s
# Train Loss: 0.0736 | Train Accuracy: 98.14%
# Validation Loss: 0.4728 | Validation Accuracy: 88.20%
# ===================================================================================================
# Epoch [16/150]: 30.78s
# Train Loss: 0.0256 | Train Accuracy: 99.38%
# Validation Loss: 0.4757 | Validation Accuracy: 91.93%
# ===================================================================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 resnet_train_losses, resnet_val_losses, resnet_train_accuracies, resnet_val_accuracies, resnet_sensitivities, resnet_specificities = train(resnet_model, 'resnet', resnet_optimizer)
#
# Cell In[9], line 34, in train(mod, name, opt)
#      31 loss.backward()
#      32 opt.step()
# ---> 34 train_loss += loss.item()
#      35 _, predicted_train = torch.max(outputs, 1)
#      36 total_train += labels.size(0)
#
# KeyboardInterrupt:

# %%
plot_graphs(resnet_train_losses, resnet_val_losses, resnet_train_accuracies, resnet_val_accuracies, resnet_sensitivities, resnet_specificities)

# %%
def test(model, name):
    model.load_state_dict(torch.load(f'best_{name}_model.pth'))

    model.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to('cuda'), labels.to('cuda')
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    test_loss /= len(test_loader)
    test_accuracy = 100 * correct / total

    print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%')

# %%
test(inception_model, 'inception')

# %%
test(resnet_model, 'resnet')

# %%
def test_ensemble(models, names):
    total_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to('cuda'), labels.to('cuda')
            ensemble_outputs = torch.zeros(inputs.size(0), num_classes).to('cuda')

            for model, name in zip(models, names):
                model.eval()
                outputs = model(inputs)
                ensemble_outputs += outputs

            ensemble_outputs /= len(models)

            loss = criterion(ensemble_outputs, labels)
            total_loss += loss.item()
            _, predicted = torch.max(ensemble_outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    test_loss = total_loss / len(test_loader)
    test_accuracy = 100 * correct / total

    print(f'Ensemble Test Loss: {test_loss:.4f}, Ensemble Test Accuracy: {test_accuracy:.2f}%')

# %%
test_ensemble([inception_model, resnet_model], ['inception', 'resnet'])
